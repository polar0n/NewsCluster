# %%
import nltk

# %%
text = None
with open('paragraphs.txt', 'r') as f:
    text = f.read()

# %%
text
# Out:
# '\n            The ATP Tour announced Tuesday that there will be no disciplinary action taken against Alexander Zverev after an investigation found insufficient evidence to substantiate published allegations of abuse.\n    \n            In October 2021, the ATP, the governing body for men’s professional tennis, said it was launching an investigation after domestic abuse allegations were made by Zverev’s former girlfriend, Olya Sharypova.\n    \n            The investigation was handled by The Lake Forest Group (LFG) with the ATP’s outside legal counsel, Smith Hulsey & Busey, serving as an intermediary.\n    \n            “Following an exhaustive 15-month process, LFG submitted its full report to ATP,” an ATP release states.\n    \n            “Based on a lack of reliable evidence and eyewitness reports, in addition to conflicting statements by Sharypova, Zverev and other interviewees, the investigation was unable to substantiate the allegations of abuse, or determine that violations 
# ...

# %%
text.split()
# Out:
# ['The',
#  'ATP',
#  'Tour',
#  'announced',
#  'Tuesday',
#  'that',
#  'there',
#  'will',
#  'be',
#  'no',
#  'disciplinary',
#  'action',
#  'taken',
#  'against',
#  'Alexander',
#  'Zverev',
#  'after',
#  'an',
#  'investigation',
#  'found',
#  'insufficient',
#  'evidence',
#  'to',
#  'substantiate',
#  'published',
#  'allegations',
#  'of',
#  'abuse.',
#  'In',
#  'October',
#  '2021,',
#  'the',
#  'ATP,',
#  'the',
#  'governing',
#  'body',
#  'for',
#  'men’s',
#  'professional',
#  'tennis,',
#  'said',
#  'it',
#  'was',
#  'launching',
#  'an',
#  'investigation',
#  'after',
#  'domestic',
#  'abuse',
#  'allegations',
#  'were',
#  'made',
#  'by',
#  'Zverev’s',
#  'former',
#  'girlfriend,',
#  'Olya',
#  'Sharypova.',
#  'The',
#  'investigation',
#  'was',
#  'handled',
#  'by',
#  'The',
#  'Lake',
#  'Forest',
#  'Group',
#  '(LFG)',
#  'with',
#  'the',
#  'ATP’s',
#  'outside',
#  'legal',
#  'counsel,',
#  'Smith',
#  'Hulsey',
#  '&',
#  'Busey,',
# ...

# %%
from nltk.tokenize import word_tokenize

# %%
nltk.download('punkt_tab')
nltk.download('averaged_perceptron_tagger_eng')
# Out:
# [nltk_data] Downloading package punkt_tab to
# [nltk_data]     C:\Users\igari\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt_tab is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger_eng to
# [nltk_data]     C:\Users\igari\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger_eng is already up-to-
# [nltk_data]       date!
# True

# %%
tokenized = word_tokenize(text)

# %%
tokenized
# Out:
# ['The',
#  'ATP',
#  'Tour',
#  'announced',
#  'Tuesday',
#  'that',
#  'there',
#  'will',
#  'be',
#  'no',
#  'disciplinary',
#  'action',
#  'taken',
#  'against',
#  'Alexander',
#  'Zverev',
#  'after',
#  'an',
#  'investigation',
#  'found',
#  'insufficient',
#  'evidence',
#  'to',
#  'substantiate',
#  'published',
#  'allegations',
#  'of',
#  'abuse',
#  '.',
#  'In',
#  'October',
#  '2021',
#  ',',
#  'the',
#  'ATP',
#  ',',
#  'the',
#  'governing',
#  'body',
#  'for',
#  'men',
#  '’',
#  's',
#  'professional',
#  'tennis',
#  ',',
#  'said',
#  'it',
#  'was',
#  'launching',
#  'an',
#  'investigation',
#  'after',
#  'domestic',
#  'abuse',
#  'allegations',
#  'were',
#  'made',
#  'by',
#  'Zverev',
#  '’',
#  's',
#  'former',
#  'girlfriend',
#  ',',
#  'Olya',
#  'Sharypova',
#  '.',
#  'The',
#  'investigation',
#  'was',
#  'handled',
#  'by',
#  'The',
#  'Lake',
#  'Forest',
#  'Group',
#  '(',
#  'LFG',
#  ')',
#  'with',
#  'the',
#  'ATP',
#  '’',
# ...

# %%
nouns = [word for (word, pos) in nltk.pos_tag(tokenized) if pos == 'NN' and word.isalpha()]

# %% [markdown]
# __POS__ - Part of Speech

# %%
nouns
# Out:
# ['action',
#  'investigation',
#  'evidence',
#  'abuse',
#  'body',
#  'tennis',
#  'investigation',
#  'abuse',
#  'girlfriend',
#  'investigation',
#  'counsel',
#  'process',
#  'report',
#  'release',
#  'lack',
#  'evidence',
#  'eyewitness',
#  'addition',
#  'investigation',
#  'abuse',
#  'place',
#  'result',
#  'action',
#  'determination',
#  'evidence',
#  'seriousness',
#  'complexity',
#  'process',
#  'ground',
#  'process',
#  'judgement',
#  'need',
#  'reason',
#  'direction',
#  'lot',
#  'work',
#  'statement',
#  'beginning',
#  'innocence',
#  'baseless',
#  'investigation',
#  'organization',
#  's',
#  'time',
#  'attention',
#  'matter',
#  'decision',
#  'arbiter',
#  'information',
#  'decision',
#  'matter',
#  'favor',
#  'addition',
#  'investigation',
#  'court',
#  'priority',
#  'injury',
#  'world',
#  'tennis',
#  'family',
#  'support',
#  'process',
#  'justice',
#  'ruling']

# %%
[word for (word, pos) in nltk.pos_tag(tokenized) if pos == 'VBP']
# Out:
# ['reveal', 'believe', '’', 'have', 'am', 'have', 'have', 'am', 'love', 'want']
