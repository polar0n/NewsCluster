# %%
import os
import json
import numpy as np

# %%
ldir = os.listdir('nouns/')

# %%
ldir
# Out:
# ['10-year-old-ukraine-boy-asleep-when-russia-drone-strike-intl-hnk.json',
#  '1000-russian-tanks-destroyed-ukraine-war-intl-hnk-ml.json',
#  '2015-paris-terror-attacks-fast-facts.json',
#  '2023-march-madness-mens-final-four-preview-spt-intl.json',
#  '2023-nfl-draft-how-to-watch-preview-spt-intl.json',
#  '2023-womens-world-cup-media-rights-infantino-spt-intl.json',
#  '70-shot-rally-kubler-khachanov-australian-open-spt-intl.json',
#  'aaron-judge-catch-yankees-jake-burger-spt-intl.json',
#  'aaron-judge-opening-day-home-run-giants-spt-intl.json',
#  'aaron-rodgers-darkness-retreat-to-start-intl-spt.json',
#  'aaron-rodgers-decision-darkness-spt-intl.json',
#  'aaron-rodgers-introduced-new-york-jets-spt-intl.json',
#  'aaron-rodgers-joe-douglas-new-york-jets-nfl-spt-intl.json',
#  'aaron-rodgers-new-york-jets-spt-intl.json',
#  'aaron-rodgers-nfl-future-darkness-intl-spt.json',
#  'aaron-rodgers-out-for-2023-season-injury-spt-intl.json',
#  'aaron-rodgers-packers-jets-nfl-spt-intl.json',
#  'aaron-rodgers-pebble-beach-pro-am-spt-intl.json',
#  'aaron-rodgers-profile-explainer-jets-packers-spt-intl.json',
#  'abortion-decriminalization-reproductive-justice-protests-intl-gbr.json',
#  'ac-milan-inter-champions-league-semifinal-preview-spt-intl.json',
#  'achraf-hakimi-rape-investigation-spt-intl.json',
#  'activists-vandalize-yacht-ibiza-climate-intl.json',
#  'adam-peaty-swimming-mental-health-spt-scli-intl-gbr.json',
#  'adele-roberts-london-marathon-ileostomy-record-spt-intl.json',
#  'adolf-hitler-birth-house-conversion-intl-scli.json',
#  'adolis-garcia-three-home-runs-rangers-athletics-spt-intl.json',
#  'adriana-lima-fifa-moya-dodd-women-world-cup-intl-spt.json',
#  'afc-playoffs-neutral-site-proposal-nfl-spt.json',
#  'afd-victory-germany-district-elections-intl.json',
#  'afd-youth-wing-extremist-label-intl.json',
#  'afghanistan-british-forces-investigation-intl.json',
#  'afl-jamarra-ugle-hagan-anti-racism-gesture-spt-intl.json',
#  'afp-journalist-arman-soldin-killed-ukraine-intl-hnk.json',
#  'african-leaders-putin-peace-meeting-intl-ukr.json',
#  'african-players-nba-basketball-africa-league-spt-spc-intl.json',
#  'ajax-groningen-match-suspended-spt-intl.json',
#  'akshay-bhatia-shirtless-mud-honda-classic-spt-intl.json',
#  'al-hilal-flamengo-club-world-cup-semifinal-spt-intl.json',
#  'alabama-baseball-coach-fired-betting-investigation.json',
#  'alabama-shooting-march-madness-brandon-miller-spt-intl.json',
#  'alan-shepard-moon-golf-apollo-remastered-photo-spt-scn-spc.json',
#  'albin-kurti-kosovo-serbia-interview-intl.json',
#  'alcaraz-injury-australian-open-tennis-intl-hnk-spt.json',
#  'alejandro-ramirez-chess-grandmaster-sexual-misconduct-allegations.json',
#  'aleksandar-mitrovic-ban-fulham-intl-spt.json',
#  'ales-bialiatski-sentenced-intl.json',
#  'alex-baena-villarreal-receives-death-threats-spt-intl.json',
#  'alex-ferguson-arsene-wenger-hall-of-fame-induction-spt-intl.json',
#  'alexander-bublik-smashes-rackets-spt-intl.json',
#  'alexander-lukashenko.json',
#  'alexander-mattison-minnesota-vikings-racist-messages.json',
#  'alexey-navalny-appeal-dismissed-intl.json',
#  'alexey-navalny-appeal-hearing-russia-intl.json',
#  'alexey-navalny-ukraine-russia-putin-intl-cmd.json',
#  'ali-riley-pride-nails-womens-world-cup-2023-spt-intl.json',
#  'alistair-brownlee-jonny-brownlee-triathlon-spt-intl.json',
#  'aliyah-boston-wnba-draft-indiana-fever-spt-intl.json',
#  'all-women-flyover-super-bowl-lvii-spt-intl.json',
#  'allisen-corpuz-win-us-womens-open-lpga-title.json',
#  'alyssa-thompson-angel-city-no-1-pick-draft-nwsl-spt-intl.json',
#  'alyssa-thompson-nwsl-draft-world-cup-spt-intl.json',
#  'alyssa-thompson-us-soccer-profile-spt-intl.json',
#  'american-dead-attack-germany-neuschwanstein-castle.json',
#  'amir-khan-banned-for-anti-doping-violations-spt-intl.json',
#  'amnesty-international-cristiano-ronaldo-saudi-arabia-spt-intl.json',
#  'amy-olson-us-open-qualified-pregnant-spt-intl.json',
#  'ana-obregon-surrogacy-debate-spain-intl.json',
#  'analysis-putin-ukraine-race-against-time-intl-hnk.json',
#  'ancient-cousins-marriage-scli-intl-scn.json',
#  'ancient-human-remains-tools-scli-intl-scn.json',
#  'anderson-comas-gay-chicago-white-sox-spt-intl.json',
#  'andrei-medvedev-wagner-defector-arrested-norway-intl.json',
#  'andrew-cogliano-broken-neck-colorado-avalanche-spt-intl.json',
#  'andrew-tate-bbc-interview-intl.json',
#  'andrew-tate-charges-trial-intl-gbr.json',
#  'andrew-tate-court-appearance-bucharest-intl.json',
#  'andrew-tate-detention-extended-intl.json',
#  'andrew-tate-house-arrest-intl.json',
#  'andrew-tate-legal-papers-intl.json',
#  'andrew-tate-rejected-appeal-romania-intl-hnk.json',
#  'andrew-tate-released-house-arrest-intl.json',
#  'andrey-rublev-ukraine-flags-australian-open-spt-intl.json',
#  'andy-murray-australian-open-beaten-spt-intl.json',
#  'andy-murray-beats-tommy-paul-aix-en-provence-spt-intl.json',
#  'andy-murray-matteo-berrettini-australian-open-spt-intl.json',
#  'andy-murray-thanasi-kokkinakis-australian-open-spt-intl.json',
#  'andy-murray-toilet-break-australian-open-spt-intl.json',
#  'angel-reese-gesture-caitlin-clark-lsu-iowa-spt-intl.json',
#  'angel-reese-jill-biden-white-house-invite-spt-intl.json',
#  'angel-reese-visit-white-house-spt-intl.json',
#  'angel-reese-white-house-jill-biden-intl-spt.json',
#  'angela-merkel---fast-facts.json',
#  'anhelina-kalinina-veronika-kudermetova-russia-ukraine-tennis-spt-intl.json',
#  'anime-inspired-russian-gangs-ukraine-intl.json',
#  'anna-cramling-chess-streamer-women-spt-intl.json',
#  'annecy-france-stabbing-attack-intl.json',
#  'anthony-bass-blue-jays-airplane-intl-spt.json',
#  'anthony-edwards-minnesota-timberwolves-assault-report.json',
#  'anthony-richardson-profile-2023-nfl-draft-spt-intl.json',
#  'anton-walkes-charlotte-fc-death-spt-intl.json',
#  'antonio-conte-leaves-tottenham-spt-intl.json',
#  'antonio-rudiger-racially-abused-cadiz-real-madrid-spt-intl.json',
#  'antonio-tiberi-cycling-cat-death-san-marino-spt-intl.json',
#  'antony-blinken-kyiv-ukraine-zelensky-intl-hnk.json',
#  'arcangelo-belmont-stakes.json',
#  'arema-persebaya-surabaya-indonesia-soccer-spt-intl.json',
#  'argentina-training-facility-named-after-messi-spt-intl.json',
#  'argentina-world-cup-muchachos-song-spt-intl.json',
#  'argentine-tattooists-messi-tributes-spt-intl.json',
#  'aristocrat-partner-arrest-missing-baby-gbr-intl-scli.json',
#  'arizona-state-sun-devils-reach-march-madness-spt-intl.json',
#  'armand-duplantis-sixth-world-record-pole-vault-spt-intl.json',
#  'armenia-azerbaijan-nagorno-karabakh-lachin-intl.json',
#  'arne-espeel-death-belgian-goalkeeper-spt-intl.json',
#  'arras-france-school-knife-attack-intl.json',
#  'arsenal-aaron-ramsdale-kicked-north-london-derby-spt-intl.json',
#  'arsenal-brentford-premier-league-var-spt-intl.json',
#  'arsenal-liverpool-premier-league-spt-intl.json',
#  'arsenal-manchester-united-premier-league-football-spt-intl.json',
#  'arsenal-newcastle-premier-league-spt-intl.json',
#  'arsenal-premier-league-title-race-southampton-spt-intl.json',
#  'arsenal-ticket-resale-spt-intl.json',
#  'aryna-sabalenka-belarus-french-open-spt-intl.json',
#  'aryna-sabalenka-elina-svitolina-french-open-spt-intl.json',
#  'aryna-sabalenka-locker-room-hate-spt-intl.json',
#  'aryna-sabalenka-zheng-qinwen-us-open-spt-intl.json',
#  'ash-barty-olivia-gadecki-intl-spt.json',
#  'ashleigh-barty-pregnancy-australian-open-spt-intl.json',
#  'ashlyn-harris-fifa-onelove-armband-spt-intl.json',
#  'asian-games-open-china-hangzhou-intl-hnk.json',
#  'asian-games-south-korea-breakdancing-intl-hnk-spt.json',
#  'athing-mu-interview-athletics-spt-intl.json',
#  'atlanta-hawks-postpone-janet-jackson-concert-spt-intl.json',
#  'atp-alexander-zverev-domestic-abuse-spt-intl.json',
#  'aukus-deal-china-tensions-analysis-intl-hnk.json',
#  'aurelien-sanchez-barkley-marathons-ultrarunning-spt-intl.json',
#  'austin-killips-tour-of-the-gila-uci-spt-intl.json',
#  'australia-95-year-old-woman-tasered-charges-intl-hnk.json',
#  'australia-95-year-old-woman-tasered-intl-hnk.json',
#  'australia-afghan-womens-team-hnk-intl-dst-spt.json',
#  'australia-afghanistan-cricket-taliban-intl-hnk-spt.json',
#  'australia-ai-images-refugee-stories-intl-hnk-dst.json',
#  'australia-antarctic-expeditioner-evacuation-mission-rsv-nuyina-intl-hnk.json',
#  'australia-ben-roberts-smith-verdict-intl-hnk.json',
#  'australia-boat-shark-attack-intl-hnk.json',
#  'australia-breastfeeding-court-intl-scli.json',
#  'australia-bushfire-la-nina-climate-intl-hnk.json',
#  'australia-bushfire-northern-territory-intl-hnk.json',
#  'australia-canada-womens-world-cup-spt-intl.json',
#  'australia-cassius-turvey-murder-charges-intl-hnk.json',
#  'australia-castaway-dog-rescue-timothy-shaddock-intl-hnk.json',
#  'australia-catamaran-cookiecutter-sharks-intl-hnk.json',
#  'australia-cherbourg-voice-referendum-intl-hnk-dst.json',
#  'australia-child-abuse-arrests-rescue-fbi-agents-intl-hnk.json',
#  'australia-childcare-worker-charged-intl-hnk.json',
#  'australia-chris-dawson-sentence-intl-hnk.json',
#  'australia-cleo-smith-kidnapper-sentenced-intl-hnk.json',
#  'australia-crocodile-missing-fisherman-intl-hnk.json',
#  'australia-cte-female-athlete-health-scn-intl-hnk.json',
#  'australia-cylinder-india-space-debris-intl.json',
#  'australia-defense-strategic-review-intl-hnk.json',
#  'australia-denmark-womens-world-cup-2023-spt-intl.json',
#  'australia-el-nino-heat-fire-summer-climate-intl.json',
#  'australia-england-womens-world-cup-semifinal-spt-intl.json',
#  'australia-excitement-wwc-semifinals-spt-intl-hnk.json',
#  'australia-france-england-colombia-womens-world-cup-quarterfinal-spt-intl.json',
#  'australia-france-reaction-sam-kerr-spt-intl.json',
#  'australia-helicopter-collision-victims-intl-hnk.json',
#  'australia-himars-missile-system-purchase-intl-hnk.json',
#  'australia-indigenous-voice-parliament-first-referendum-intl-hnk.json',
#  'australia-indigenous-world-cup-legacy-spt-intl-hnk-dst.json',
#  'australia-invasion-day-indigenous-voice-intl-hnk-dst.json',
#  'australia-kangaroo-culling-program-intl-hnk-dst.json',
#  'australia-kathleen-folbigg-attorney-general-hnk-intl.json',
#  'australia-kathleen-folbigg-pardon-intl-hnk-dst.json',
#  'australia-man-fake-kidnap-meet-mistress-intl-hnk.json',
#  'australia-man-overboard-royal-caribbean-cruise-ship-intl-hnk.json',
#  'australia-masterchef-jock-zonfrillo-dead-intl-hnk.json',
#  'australia-matildas-soccer-womens-world-cup-2023-spt-intl-hnk.json',
#  'australia-matildas-wwc-equal-pay-video-spt-intl-hnk.json',
#  'australia-matildas-wwc-loss-england-spt-intl-hnk.json',
#  'australia-melissa-caddick-fraud-coroner-death-intl-hnk.json',
#  'australia-ned-kelly-emeralds-detainee-intl-hnk-dst.json',
#  'australia-nsw-birth-trauma-inquiry-intl-hnk-dst.json',
#  'australia-open-2024-sunday-start-15-day-tournament-hnk-spt-intl.json',
#  'australia-parasitic-worm-brain-scn-intl-hnk.json',
#  'australia-philippines-children-rescued-intl-hnk.json',
#  'australia-poison-mushroom-hospital-release-intl-hnk.json',
#  'australia-poison-mushroom-meal-intl-hnk.json',
#  'australia-poison-mushroom-statement-intl-hnk.json',
#  'australia-police-search-missing-woman-intl-hnk.json',
#  'australia-record-heat-bushfire-threat-climate-intl-hnk.json',
#  'australia-referendum-results-intl-hnk.json',
#  'australia-russian-embassy-lease-intl-latam.json',
#  'australia-seismic-blasting-whales-climate-intl-hnk.json',
#  'australia-snorkeler-escapes-crocodile-jaws-intl-hnk.json',
#  'australia-soldiers-missing-in-helicopter-crash-wargames-intl-hnk.json',
#  'australia-south-africa-women-t20-world-cup-spt-intl.json',
#  'australia-surf-club-nudity-policy-intl-spt-scli.json',
#  'australia-surfing-python-snake-fine-gold-coast-intl-hnk.json',
#  'australia-sweden-womens-world-cup-2023-spt-intl.json',
#  'australia-the-office-felicity-ward-first-female-lead-intl-hnk.json',
#  'australia-tomahawk-missiles-aukus-intl-hnk.json',
#  'australia-torture-united-nations-inspections-intl-hnk.json',
#  'australia-us-fighter-pilot-extradition-hearing-intl-hnk.json',
#  'australia-us-pilot-daniel-duggan-singled-out-intl-hnk.json',
#  'australia-vaping-ban-intl-hnk.json',
#  'australia-victoria-2026-commonwealth-games-canceled-spt-intl-hnk.json',
#  'australia-voice-referendum-date-intl-hnk.json',
#  'australia-voice-referendum-division-intl-dst-hnk.json',
#  'australia-voice-referendum-rallies-intl-hnk.json',
#  'australia-voice-referendum-vote-intl-hnk.json',
#  'australia-william-leslie-arnold-cold-case-intl-hnk-dst.json',
#  'australia-woman-wall-remains-investigation-intl-hnk.json',
#  'australia-worker-praise-afp-comments-intl-hnk.json',
#  'australia-world-surfing-record-sydney-intl-hnk.json',
#  'australian-cricket-racism-allegations-spt-intl.json',
#  'australian-open-2023-djokovic-nadal-swiatek-spt-intl.json',
#  'australian-open-draw-nadal-djokovic-swiatek-spt-intl.json',
#  'australian-open-heat-day-two-spt-intl.json',
#  'australian-open-how-to-watch-day-one-spt-intl.json',
#  'australian-open-how-to-watch-day-two-spt-intl.json',
#  'australian-open-inappropriate-flags-symbols-spt-intl.json',
#  'australian-open-late-finish-andy-murray-spt-intl.json',
#  'australian-open-tennis-russian-flag-spt-intl.json',
#  'australian-prime-minister-mardi-gras-intl.json',
#  'austria-melting-glacier-body-discovered-climate-intl-scli.json',
#  'austrian-mountain-fluchthorn-rockslide-climate-intl.json',
#  'azovastal-mariupol-siege-talks-intl-cmd.json',
#  'azovstal-leaders-return-ukraine-intl-hnk.json',
#  'baffert-churchill-downs-ban-lift-denied.json',
#  'bahrain-grand-prix-formula-one-spt-intl.json',
#  'bakhmut-ben-wedeman-report-intl.json',
#  'bakhmut-capture-wagner-russia-ukraine-intl.json',
#  'bakhmut-capture-wagner-ukraine-russia-intl.json',
#  'bakhmut-control-ukraine-russia-intl.json',
#  'bakhmut-counterattacks-underway-intl.json',
#  'bakhmut-ukraine-counter-offensive-intl.json',
#  'bakhmut-ukraine-explainer-russian-military-intl.json',
#  'bakhmut-ukraine-orthodox-christmas-intl-cmd.json',
#  'bakhmut-wagner-yevgeny-prigozhin-intl-cmd.json',
#  'bali-world-beach-games-indonesia-canceled-intl-hnk-spt.json',
#  'baltimore-orioles-pittsburgh-pirates-umpires-spt-intl.json',
#  'barack-obama-march-madness-bracket-spt-intl.json',
#  'barbora-krejcikova-iga-swiatek-dubai-tennis-championships-spt-intl.json',
#  'barcelona-atletico-madrid-la-liga-spt-intl.json',
#  'barcelona-femeni-win-record-spt-intl.json',
#  'barcelona-into-womens-champions-league-final-chelsea-spt-intl.json',
#  'barcelona-lamine-yamal-youngest-ever-player-spt-intl.json',
#  'barcelona-laporta-referee-scandal-payment-laliga-spt-intl.json',
#  'barcelona-manchester-united-europa-league-spt-intl.json',
#  'barcelona-spanish-super-cup-real-madrid-spt-intl.json',
#  'barcelona-turnaround-to-la-liga-champion-spt-intl.json',
#  'barcelona-villarreal-la-liga-spt-intl.json',
#  'barcelona-win-real-madrid-el-clasico-la-liga-spt-intl.json',
#  'barcelona-wolfsburg-womens-champions-league-final-spt-intl.json',
#  'barkley-marathons-finishers-trnd.json',
#  'baseball-home-runs-air-temperature-climate-scn.json',
#  'basketball-coach-allegedly-poses-player-intl-spt.json',
#  'basketball-florida-atlantic-final-four-kansas-state.json',
#  'battle-waterloo-bones-scli-intl-scn.json',
#  'bayern-munich-borussia-dortmund-bundesliga.json',
#  'bayern-munich-sacks-julian-nagelsmann-spt-intl-hnk.json',
#  'bbc-apologizes-inappropriate-question-ghizlane-chebbak-spt-intl.json',
#  'bbc-presenter-allegations-intl.json',
#  'bbc-presenter-second-person-allegations-intl-gbr.json',
#  'bbc-presenter-sexual-misconduct-intl-hnk.json',
#  'bbc-presenter-teen-intl-gbr.json',
#  'bear-skins-prehistoric-clothing-scn.json',
#  'bears-panthers-nfl-draft-trade-spt-intl.json',
#  'beheading-videos-ukraine-intl-hnk-ml.json',
#  'belarus-leader-invites-wagner-train-military-intl-hnk.json',
#  'belarus-nobel-peace-laureate-ales-bialiatski-intl.json',
#  'belarus-red-cross-ukraine-children-deportations-intl.json',
#  'belarus-ukraine-troops-russia-border-intl.json',
#  'belarus-us-pushing-russia-to-nukes-intl-hnk.json',
#  'belarus-wagner-fighters-poland-intl.json',
#  'belarus-wagner-prigozhin-lukashenko-russia-intl-hnk.json',
#  'belgian-tourist-missing-australia-tasmania-intl-hnk.json',
#  'belgium-brussels-shooting-intl.json',
#  'belgium-destroys-beer-champagne-intl-hnk.json',
#  'belgorod-attacks-russia-ukraine-explainer-intl.json',
#  'belgorod-ukrainian-forces-russian-territory-intl.json',
#  'bella-simoes-youngest-us-womens-open-spt-intl.json',
#  'ben-gvir-visit-israel-jerusalem-intl.json',
#  'ben-shelton-frances-tiafoe-us-open-spt.json',
#  'ben-shelton-frances-tiafoe-us-open.json',
#  'ben-shelton-profile-australian-open-spt-intl.json',
#  'benjamin-mendy-2nd-trial-manchester-city-acquittal-intl-hnk.json',
#  'benjamin-mendy-trial-manchester-city-spt-intl.json',
#  'berlin-synagogue-motolov-cocktails-attack-intl.json',
#  'berlin-wall-fast-facts.json',
#  'berlusconi-back-in-hospital-italy-intl-hnk.json',
#  'berry-henson-us-open-qualify-uber-spt-intl.json',
#  'besiktas-football-turkey-earthquake-spt-intl.json',
#  'beslan-school-siege-fast-facts.json',
#  'bethany-hamilton-wsl-surfing-transgender-policy-spt-intl.json',
#  'bibby-stockholm-asylum-barge-safety-intl-gbr.json',
#  'bibby-stockholm-barge-asylum-seekers-intl-gbr.json',
#  'bibby-stockholm-legionnaires-disease-gbr-intl.json',
#  'biden-irish-cousins-intl-cmd.json',
#  'biden-russia-hypersonic-missiles-explainer-intl-hnk.json',
#  'biden-ukraine-comments-nato-analysis-intl.json',
#  'bilbao-fans-protest-barcelona-la-liga-spt-intl.json',
#  'bill-self-kansas-jayhawks-head-coach-spt-intl.json',
#  'bill-self-release-hospital-kansas-march-madness-spt-intl.json',
#  'black-raf-pilot-of-the-caribbean-funeral-intl.json',
#  'black-sea-fleet-attacks-ukraine-russia-intl-hnk.json',
#  'black-sea-grain-deal-deadline-intl.json',
#  'black-sea-grain-deal-extension-intl-ukr.json',
#  'blackpool-fan-death-burnley-football-spt-intl.json',
#  'bmx-hot-air-balloon-parachute-stunt-spt-intl.json',
#  'boat-capsize-italy-lake-maggiore-intl.json',
#  'bob-baffert-churchill-downs-suspension-spt-intl.json',
#  'bob-baffert-lawsuit-churchill-downs-spt.json',
#  'bob-brown-football-death-spt.json',
#  'bob-huggins-dui-coach-west-virginia-basketball.json',
#  'bob-huggins-west-virginia-salary-suspension-spt-intl.json',
#  'bob-myers-step-down-golden-state-warriors-spt-intl.json',
#  'bobby-beathard-nfl-executive-dies.json',
#  'bobby-bonilla-day-mets-mlb-spt-trnd.json',
#  'bobby-hull-hockey-death-spt-intl.json',
#  'bobi-oldest-ever-dog-dies-intl-scli.json',
#  'bobi-worlds-oldest-ever-dog-intl-scli.json',
#  'bog-bodies-study-scn.json',
#  'bonnie-prince-charlie-real-face-intl-scli-scn-gbr.json',
#  'boris-becker-alex-gibney-documentary-spt-intl.json',
#  'boris-johnson-analysis-intl-gbr.json',
#  'boris-johnson-british-politics-intl-cmd.json',
#  'boris-johnson-carrie-third-child-intl-scli-gbr.json',
#  'boris-johnson-evidence-partygate-hearing-intl-cmd-gbr.json',
#  'boris-johnson-fall-analysis-uk-intl.json',
#  'boris-johnson-fast-facts.json',
#  'boris-johnson-labour-uxbridge-byelection-gbr-cmd-intl.json',
#  'boris-johnson-parliament-vote-intl-gbr.json',
#  'boris-johnson-partygate-evidence-intl-gbr.json',
#  'boris-johnson-select-committee-report-intl-gbr.json',
#  'boris-johnson-ukraine-nato-interview-intl.json',
#  'boston-bruins-collapse-florida-panthers-nhl-spt.json',
#  'boston-bruins-nhl-record.json',
#  'boston-celtics-30-wins-pelicans-nba-spt-intl.json',
#  'boston-celtics-miami-heat-game-4-spt-intl.json',
#  'boston-celtics-miami-heat-game-5-spt-intl.json',
#  'boston-celtics-miami-heat-game-6-spt-intl.json',
#  'boston-celtics-miami-heat-game-7-nba-playoffs-spt-intl.json',
#  'boston-marathon-2023-preview-spt-intl.json',
#  'botulism-death-france-scli-intl.json',
#  'bowling-green-basketball-struck-memphis-spt-intl.json',
#  'boxing-olympics-chaos-iba-usa-spt-intl.json',
#  'brad-daugherty-daytona-500-black-owner-spt-intl.json',
#  'brad-pitt-f1-film-intl-spt-scli.json',
#  'brandon-canesi-adaptive-golf-spt-spc-intl.json',
#  'brandon-miller-alabama-basketball-spt-intl.json',
#  'brandon-miller-alabama-declares-for-nba-draft-spt-intl.json',
#  'brandon-miller-speaks-alabama-shooting-spt-intl.json',
#  'braves-ronald-acuna-40-40-club-atlanta-spt-intl.json',
#  'braves-ronald-acuna-on-field-fan-encounter.json',
#  'brazil-germany-panama-morocco-womens-world-cup-2023-spt-intl.json',
#  'brazil-jamaica-france-panama-womens-world-cup-spt-intl.json',
#  'brazil-soccer-match-fixing-investigation-spt-intl.json',
#  'break-point-netflix-tennis-spt-intl.json',
#  'brendan-malone-nba-dies.json',
#  'brentford-ivan-toney-racial-abuse-spt-intl.json',
#  'brentford-moneyball-success-premier-league-spt-intl.json',
#  'brexit-northern-ireland-negotiations-gbr-intl.json',
#  'brian-flores-judge-lawsuit-nfl-spt-intl.json',
#  'brian-harman-open-championship-2023-winner-spt-intl.json',
#  'brianna-ghey-murder-charge-gbr-intl-scli.json',
#  'britain-rishi-sunak-climate-policies-analysis-gbr-intl.json',
#  'british-army-serviceman-terrorism-charges-intl-hnk.json',
#  'british-girl-shot-dead-france-intl.json',
#  'british-open-golf-tournament-fast-facts.json',
#  'british-tourists-egypt-boat-fire-intl.json',
#  'brittney-griner-dallas-airport-harassment.json',
#  'brittney-griner-phoenix-mercury-mental-health.json',
#  'brittney-griner-phoenix-mercury-one-year-deal-spt.json',
#  'brittney-griner-phoenix-mercury-travel-safety.json',
#  'brittney-griner-press-conference-phoenix-mercury-spt-intl.json',
#  'brittney-griner-return-phoenix-mercury-spt-intl.json',
#  'brittney-griner-return-wnba-all-star-game.json',
#  'brittney-griner-wnba-all-star-spt.json',
#  'brittney-griner-wnba-phoenix-mercury-return-spt-intl.json',
#  'brittney-griner-wnba-phoenix-mercury-spt-intl.json',
#  'bronny-james-cardiac-arrest-screening.json',
#  'bronny-james-cardiac-arrest.json',
#  'bronny-james-heart-defect.json',
#  'bronny-james-usc-lebron-son-spt-intl.json',
#  'brooks-koepka-corey-conners-pga-championship-spt-intl.json',
#  'brooks-koepka-funk-major-spt-spc-intl.json',
#  'brooks-lebron-grizzlies-lakers-game-2-spt-intl.json',
#  'bruno-fernandes-manchester-united-fan-spt-intl.json',
#  'brussels-suicide-bombing-guilty-intl.json',
#  'bryan-brothers-tennis-french-open-spt-intl.json',
#  'bryansk-alleged-sabotage-operation-russia-ukraine-intl.json',
#  'bryansk-russia-border-incident-ukraine-intl.json',
#  'bryce-young-announce-2023-nfl-draft-alabama-spt-intl.json',
#  'bryson-dechambeau-kenny-pigman-pga-championship-spt-intl.json',
#  'bryson-dechambeau-pga-tour-liv-golf-spt-intl.json',
#  'bts-suga-nba-basketball-ambassador-spt-intl.json',
#  'bucha-ukraine-russian-occupation-rebuilding-intl.json',
#  'buckingham-palace-protest-intl-gbr.json',
#  'bud-grant-vikings-nfl-coach-death.json',
#  'buffalo-bills-damar-hamlin-recovery-monday-spt.json',
#  'buffalo-bills-damar-hamlin-recovery-tuesday-spt.json',
#  'buffalo-bills-kansas-city-chiefs-atlanta-spt-intl.json',
#  'buffalo-bills-new-england-patriots-damar-hamlin-spt-intl.json',
#  'buffalo-bills-nyheim-hines-touchdown-damar-hamlin-spt-intl.json',
#  'buffalo-bills-playoff-preview-stats-spt-intl.json',
#  'buffalo-sabres-damar-hamlin-capitals-spt-intl.json',
#  'buffalo-shooting-daniel-harris-jailed-intl-gbr.json',
#  'bulgaria-migrant-truck-deaths-intl.json',
#  'bundesliga-final-day-2023-dortmund-bayern-spt-intl.json',
#  'byron-jones-nfl-injuries-spt-intl.json',
#  'cadbury-creme-eggs-thief-jailed-scli-gbr-intl.json',
#  'caf-condemns-fan-behavior-champions-league-death-spt-intl.json',
#  'caitlin-clark-defend-angel-reese-gesture-spt-intl.json',
#  'caitlin-clark-march-madness-final-four-spt-intl.json',
#  'caitlin-clark-march-madness-record-breaker-spt-intl.json',
#  'calabrian-mafia-raids-europe-intl.json',
#  'california-horse-racing-deaths-spt.json',
#  'cam-thomas-nba-fine-spt-intl.json',
#  'cameron-smith-open-celebrations-australian-pga-spt-spc-intl.json',
#  'cameron-young-golf-cart-us-open-spt-intl.json',
#  'camilla-queen-explainer-gbr-intl-scli.json',
#  'campbell-johnstone-all-blacks-rugby-spt-intl.json',
#  'campbell-johnstone-gay-rugby-new-zealand-spt-intl.json',
#  'canada-soccer-pay-dispute-intl-spt.json',
#  'canada-spain-japan-2023-womens-world-cup-spt-intl.json',
#  'canada-wildfires-norway-smoke-climate-intl.json',
#  'canada-women-soccer-strike-called-off-spt-intl.json',
#  'canada-women-soccer-strike-spt-intl.json',
#  'canary-islands-migrant-boat-intl.json',
#  'cannibalism-funeral-ritual-intl-scli-scn.json',
#  'captured-russian-soldiers-ukraine-intl-cmd.json',
#  'cardiff-police-riots-car-crash-intl-gbr.json',
#  'cardinal-george-pell-funeral-intl.json',
#  'carlos-alcaraz-argentina-open-tennis-spt-intl.json',
#  'carlos-alcaraz-indian-wells-injury-return-spt-intl.json',
#  'carlos-correa-minnesota-twins-return-spt-intl.json',
#  'carlsen-nakamura-airthings-masters-grand-final-spt-intl.json',
#  'carmelo-anthony-announces-retirement-spt-intl.json',
#  'carolina-panthers-frank-reich-head-coach-spt-intl.json',
#  'caroline-kennedy-jfk-world-war-ii-swim-intl-hnk.json',
#  'carolyn-kindle-st-louis-city-mls-spt-intl.json',
#  'casey-phair-south-korea-womens-world-cup-intl-hnk-spt.json',
#  'casper-ruud-jenson-brooksby-australian-open-spt-intl.json',
#  'cece-telfer-athletics-spt-intl.json',
#  'chad-johnson-nfl-cincinnati-bengals-spt-intl.json',
#  'champions-league-man-city-real-madrid-semifinal-spt-intl.json',
#  'champions-league-quarterfinal-draw-spt-intl.json',
#  'championship-playoff-2023-final-luton-coventry-preview-spt-intl.json',
#  'charles-disappointed-at-boy-harry-born-diana-recordings-intl-hnk.json',
#  'charlotte-george-wimbledon-mens-final-scli-spt-intl.json',
#  'chelsea-barcelona-womens-champions-league-semifinal-spt-intl.json',
#  'chelsea-champions-league-win-borussia-dortmund-spt-intl.json',
#  'chelsea-graham-potter-manager-premier-league-spt-intl.json',
#  'chelsea-manchester-united-womens-fa-cup-spt-intl.json',
#  'chelsea-todd-boehly-billionaire-no-success-spt-intl.json',
#  'chelsea-transfers-todd-boehly-spt-intl.json',
#  'chess-champions-tour-new-era-spt-intl.json',
#  'chess-variants-explainer-spt-intl.json',
#  'chevron-championship-watch-time-preview-spt-intl.json',
#  'chicago-blackhawks-pride-jersey-intl-spt.json',
#  'chicago-white-sox-liam-hendriks-lymphoma.json',
#  'chief-rabbi-king-charles-coronation-intl-scli-gbr.json',
#  'china-alleged-spy-uk-parliament-intl-gbr-cmd.json',
#  'china-ambassador-australia-japan-attack-comment-intl-hnk.json',
#  'china-made-drone-downed-eastern-ukraine-hnk-intl.json',
#  'china-opera-singer-mariupol-intl.json',
#  'china-womens-soccer-team-ambitions-wwc-intl-hnk-spt.json',
#  'china-xi-russia-putin-talks-five-takeaways-intl-hnk-mic.json',
#  'china-xi-russia-putin-visit-day-two-talks-intl-hnk.json',
#  'china-zhang-weili-mma-ufc-intl-hnk-spt.json',
#  'chinese-snooker-bans-intl-hnk-spt.json',
#  'chocolate-egg-thief-scli-gbr-intl.json',
#  'chonhar-bridge-strike-ukraine-intl.json',
#  'chris-hughes-maitlan-brown-barbie-bbc-spt-intl-scli.json',
#  'chris-kirk-alcoholism-depression-honda-classic-spt-intl.json',
#  'chris-maragos-wins-medical-malpractice-case-spt-intl.json',
#  'chris-snow-death.json',
#  'christian-atsu-funeral-spt-intl.json',
#  'christian-atsu-turkey-earthquake-missing-intl-spt.json',
#  'christian-atsu-turkey-earthquake-update-spt-intl.json',
#  'christian-eriksen-cardiac-arrest-comeback-spt-intl.json',
#  'christian-eriksen-cardiac-arrest-return-spt-intl.json',
#  'christo-grozev-baftas-navalny-documentary-intl.json',
#  'church-england-single-jesus-intl-gbr-scli.json',
#  'churchill-downs-horse-deaths-safety-measures.json',
#  'churchill-downs-horse-deaths-spt.json',
#  'churchill-downs-kentucky-derby-horse-deaths-spt-inl.json',
#  'churchill-downs-suspends-trainer-saffie-joseph-jr.json',
#  'churchill-downs-suspension-horse-deaths.json',
#  'cincinnati-bengals-buffalo-bills-dallas-cowboys-san-francisco-49ers-spt-intl.json',
#  'cincinnati-bengals-joe-burrow-nfl-fixtures-hamlin-spt-intl.json',
#  'ciro-immobile-lazio-soccer-crash-spt-intl.json',
#  'clarisse-cremer-alex-thomson-sailing-vendee-globe-spt-intl.json',
#  'claudia-vasconcelos-female-referee-1991-womens-world-cup-spt-intl.json',
#  'climate-activists-dye-spanish-steps-intl.json',
#  'climate-lawsuit-switzerland-european-court-intl.json',
#  'climate-protest-world-snooker-championship-spt-intl.json',
#  'club-world-cup-real-madrid-morocco-spt-intl.json',
#  'cluster-munitions-us-ukraine-aid-explainer-intl-hnk-ml.json',
#  'cocaine-440-million-haul-italy-intl-scli.json',
#  'cocaine-drug-bust-australia-us-intl.json',
#  'coco-gauff-aryna-sabalenka-us-open-spt-intl.json',
#  'coco-gauff-emma-raducanu-australian-open-spt-intl.json',
#  'coco-gauff-iga-swiatek-french-open-spt-intl.json',
#  'coco-gauff-jimmy-butler-nba-finals-spt-intl.json',
#  'coco-gauff-karolina-muchova-us-open-spt-intl.json',
#  'coco-gauff-mirra-andreeva-french-open-spt-intl.json',
#  'cody-ware-nascar-suspended.json',
#  'colin-kaepernick-adoptive-parents-spt-intl.json',
#  'college-football-playoffs-2022-results.json',
#  'colombia-jamaica-france-morocco-womens-world-cup-spt-intl.json',
#  'colombia-morocco-germany-south-korea-womens-world-cup-spt-intl.json',
#  'colombian-fan-attack-millionarios-tolima-spt-intl.json',
#  'colorado-state-apology-russia-chant-utah-state.json',
#  'commentator-david-basheer-criticized-for-katrina-gorry-comment-spt-intl.json',
#  'conor-benn-doping-analysis-reaction-spt-intl.json',
#  'conor-mcgregor-mascot-heat-trnd.json',
#  'constance-marten-mark-gordon-baby-body-intl.json',
#  'corey-pereira-girlfriend-cancer-us-open-spt-intl.json',
#  'coronation-concert-prince-william-scli-intl-ckc-gbr.json',
#  'coronation-king-charles-ckc-gbr-intl.json',
#  'coronation-king-charles-key-moments-ckc-gbr-intl-scli.json',
#  'coronation-king-charles-order-of-service-gbr-intl-ckc.json',
#  'coronation-of-king-charles-iii-preview-gbr-cmd-intl.json',
#  'coronation-official-portraits-intl-gbr-ckc.json',
#  'courtney-dauwalter-ultramarathon-spt-intl.json',
#  'coy-wire-buffalo-damar-hamlin-reflections-spt.json',
#  'craig-breen-rally-driver-death-spt-intl.json',
#  'crimea-bridge-putin-explainer-intl.json',
#  'crimea-missile-attack-ukraine-russia-intl.json',
#  'crimea-road-bridge-explosions-intl.json',
#  'crimea-russian-missiles-destroyed-ukraine-intl-hnk.json',
#  'crimea-russian-tourists-intl.json',
#  'crimea-ukraine-raids-jet-skis-intl-cmd.json',
#  'crimean-tatar-soldier-ukraine-intl-cmd.json',
#  'cristiano-ronaldo-500-club-goals-spt-intl.json',
#  'cristiano-ronaldo-al-nassr-spt-intl.json',
#  'cristiano-ronaldo-celebration-portugal-spt-intl.json',
#  'cristiano-ronaldo-first-goal-al-nassr.json',
#  'cristiano-ronaldo-forbes-highest-paid-athletes-spt-intl.json',
#  'cristiano-ronaldo-legal-fees-rape-allegation-reimbursed-intl-spt.json',
#  'cristiano-ronaldo-sajdah-goal-celebration-spt-intl.json',
#  'cristiano-ronaldo-saudi-arabia-transfer-window-spt-intl.json',
#  'crown-princess-leonor-spain-military-training-intl-scli.json',
#  'cuba-womens-boxing-olympics-spt-intl.json',
#  'cuban-catcher-defects-world-baseball-classic-spt-intl.json',
#  'cui-chenxi-wins-gold-asian-games-skateboard-intl-hnk-spt.json',
#  'cyclone-ilsa-new-speed-record-australia-intl-hnk.json',
#  'cyclone-ilsa-western-australia-intl-hnk.json',
#  'cyclone-ilsa-western-australia-thursday-intl-hnk.json',
#  'czech-election-petr-pavel-win-intl.json',
#  'd-day-fast-facts.json',
#  'daewood-davis-miami-dolphins-injury-spt.json',
#  'dagestan-russia-gas-station-fire-intl.json',
#  'dallas-cowboys-disappointing-loss-49ers-nfl-playoffs-spt-intl.json',
#  'dallas-mavericks-fined-nba-draft-spt-intl.json',
#  'dallas-stars-seattle-kraken-game-7-nhl-spt-intl.json',
#  'damar-hamlin-bills-jets-inactive-spt-intl.json',
#  'damar-hamlin-brandon-beane-buffalo-bills-spt-intl.json',
#  'damar-hamlin-buffalo-bills-bengals-nfl-spt-intl.json',
#  'damar-hamlin-buffalo-bills-cincinnati-bengals-playoffs-spt.json',
#  'damar-hamlin-buffalo-bills-collapse.json',
#  'damar-hamlin-buffalo-bills-hospital-release-spt.json',
#  'damar-hamlin-buffalo-bills-playoffs-spt-intl.json',
#  'damar-hamlin-buffalo-bills-practice-spt-intl.json',
#  'damar-hamlin-chiefs-jaguars-nfl-spt-intl.json',
#  'damar-hamlin-cleared-to-train-nfl-spt-intl.json',
#  'damar-hamlin-collapse-bills-status-saturday.json',
#  'damar-hamlin-collapse-bills-status-thursday.json',
#  'damar-hamlin-collapse-bills-status-wednesday.json',
#  'damar-hamlin-cpr-initiative-spt-intl.json',
#  'damar-hamlin-espy-awards-bills-tribute.json',
#  'damar-hamlin-full-practice-buffalo-bills-spt-intl.json',
#  'damar-hamlin-george-halas-award-spt-intl.json',
#  'damar-hamlin-health-update-nfl-spt-intl.json',
#  'damar-hamlin-jacket-super-bowl-lvii-spt-intl.json',
#  'damar-hamlin-jessica-pegula-australian-open-spt-intl.json',
#  'damar-hamlin-john-petrishen-teammate-cardiac-arrest-spt-intl.json',
#  'damar-hamlin-media-reaction-spt-intl.json',
#  'damar-hamlin-nfl-players-union-doctor-spt-intl.json',
#  'damar-hamlin-nfl-response-spt-intl.json',
#  'damar-hamlin-pads-buffalo-bills-practice-spt-intl.json',
#  'damar-hamlin-profile-buffalo-bills-spt-intl.json',
#  'damar-hamlin-recovery-buffalo-bills-spt-intl.json',
#  'damar-hamlin-thanks-first-responders-fans.json',
#  'damar-hamlin-update-sean-mcdermott-bills-spt-intl.json',
#  'damian-lillard-71-points-record-nba-spt-intl.json',
#  'damian-lillard-portland-trail-blazers-nba-60-points-spt-intl.json',
#  'dana-white-ufc-domestic-violence-spt-intl.json',
#  'dane-jackson-kayak-santo-domingo-gorge-mexico-spt-intl.json',
#  'dani-alves-catalonia-higher-court-of-justice-spt-intl.json',
#  'dani-alves-detained-barcelona-spt-intl.json',
#  'dani-alves-jailed-spanish-court-spt-intl.json',
#  'dania-akeel-dakar-rally-spt-intl.json',
#  'daniel-abed-khalife-prison-escape-criticism-intl-gbr.json',
#  'daniel-bard-anxiety-spt-intl.json',
#  'daniel-khalife-recaptured-intl-gbr.json',
#  'danielle-collins-celebrate-too-early-australian-open-spt-intl.json',
#  'danielle-kang-spinal-tumor-comeback-spc-spt-intl.json',
#  'danielle-kang-spine-tumor-golf-lpga-spt-spc-intl.json',
#  'daniil-martynov-russia-turkey-earthquake-intl.json',
#  'daniil-medvedev-heat-andrey-rublev-us-open-spt-intl.json',
#  'daniil-medvedev-holger-rune-italian-open-tennis-spt-intl.json',
#  'dante-vanzeir-new-york-red-bulls-mls-suspension-spt.json',
#  'dante-vanzeir-new-york-red-bulls-racism-mls-spt-intl.json',
#  'daria-kasatkina-ukraine-tennis-players-spt-intl.json',
#  'darren-drozdov-death.json',
#  'david-cameron---fast-facts.json',
#  'david-vencl-free-dive-record-frozen-lake-spt-scli-intl.json',
#  'davy-klaassen-ajax-injured-spt-intl.json',
#  'daytona-500-nascar-2023-preview-spt.json',
#  'daytona-500-ricky-stenhouse-win.json',
#  'deion-sanders-colorado-buffaloes-mascot-spt-intl.json',
#  'deion-sanders-foot-amputation-risk-spt.json',
#  'delilah-wales-rugby-tom-jones-spt-intl.json',
#  'demar-derozan-daughter-bulls-raptors-play-in-spt-intl.json',
#  'demar-diar-derozan-offered-flight-bulls-heat-spt-intl.json',
#  'dennis-ombachi-rugby-sevens-tik-tok-spt-intl.json',
#  'denny-kellington-bills-damar-hamlin-cpr.json',
#  'denver-broncos-saints-sean-payton-nfl-spt-intl.json',
#  'denver-nuggets-nba-championship-spt-intl.json',
#  'denver-nuggets-phoenix-suns-nikola-jokic-spt-intl.json',
#  'depleted-uranium-munitions-explainer-intl.json',
#  'derek-carr-las-vegas-raiders-nfl-spt-intl.json',
#  'desjuan-johnson-mr-irrelevant-nfl-draft-spt-intl.json',
#  'diana-taurasi-wnba-league-points-record.json',
#  'dick-butkus-death-illinois-bears.json',
#  'dick-fosbury-high-jump-obit-spt-intl.json',
#  'diego-maradona-hand-of-god-ball-auction-spt-intl.json',
#  'ding-liren-world-chess-champion-spt-intl.json',
#  'dinosaur-footprints-isle-of-wight-gbr-scli-scn-intl.json',
#  'dion-dawkins-damar-hamlin-buffalo-bills-spt-intl.json',
#  'djokovic-alcaraz-cincinnati-tennis-spt-intl.json',
#  'djokovic-father-z-symbol-russia-intl-spt.json',
#  'djokovic-us-tennis-participation-intl-spt.json',
#  'djokovic-vaccine-miami-open-tennis-spt-intl-hnk.json',
#  'dmitry-medvedev---fast-facts.json',
#  'dnipro-medical-facility-attack-russia-ukraine-intl.json',
#  'dnipro-ukraine-war-russian-missile-strike-intl.json',
#  'dog-catches-baseball-spring-training-spt-intl.json',
#  'domingo-german-ejected-yankees-blue-jays-spt-intl.json',
#  'dommaraju-gukesh-17th-birthday-magnus-carlsen-spt-intl.json',
#  'dommaraju-gukesh-nodirbek-abdusattorov-norway-chess-spt-intl.json',
#  'donald-trump-pga-tour-liv-golf-partnership-reaction-spt-intl.json',
#  'donna-kelce-jason-travis-super-bowl-lvii-spt-intl.json',
#  'donna-kelce-travis-jason-super-bowl-nfl-spt-intl.json',
#  'donovan-mitchell-cleveland-cavaliers-nba.json',
#  'downhill-skateboarding-woolf-women-intl-spt.json',
#  'downing-street-car-crash-gbr-intl.json',
#  'doyle-brunson-godfather-of-poker-died-spt-intl.json',
#  'draymond-green-golden-state-warriors-suspension-spt.json',
#  'draymond-green-sabonis-kings-warriors-game-2-spt-intl.json',
#  'duangphet-phromthep-thai-cave-dies-intl.json',
#  'duchess-camilla-fast-facts.json',
#  'dutch-government-collapses-rutte-elections-intl.json',
#  'dutch-king-apologizes-netherlands-slavery-intl.json',
#  'dutch-police-arrest-154-antisemitic-chants-intl-hnk.json',
#  'e-40-sacramento-kings-warriors-ejection-spt-intl.json',
#  'earthquake-hits-turkey-intl-hnk.json',
#  'eddie-howe-leeds-united-assault-spt-intl.json',
#  'edinburgh-scotland-ship-accident-intl-gbr.json',
#  'edwin-diaz-world-baseball-classic-injury-spt-intl.json',
#  'el-clasico-barcelona-real-madrid-la-liga-spt-intl.json',
#  'elena-rybakina-iga-swiatek-indian-wells-spt-intl.json',
#  'elena-rybakina-victoria-azarenka-aryna-sabalenka-magda-linette-australian-open-semifinal-spt-intl.json',
#  'elina-svitolina-daria-kasatkina-french-open-ukraine-spt-intl.json',
#  'elina-svitolina-gael-monfils-french-open-spt-intl.json',
#  'elina-svitolina-olympics-tennis-russia-ukraine-tennis-spt-intl.json',
#  'elon-musk-germany-migrant-debate-intl.json',
#  'elton-john-manchester-city-fa-cup-spt-intl.json',
#  'emilia-romagna-grand-prix-canceled-flooding-spt-intl.json',
#  'emiliano-grillo-win-charles-schwab-challenge-spt-intl.json',
#  'emma-raducanu-indian-wells-injuries-spt-intl.json',
#  'emma-raducanu-injury-auckland-classic-tennis-spt-intl-hnk.json',
#  'emma-raducanu-into-last-16-indian-wells-spt-intl.json',
#  'emma-raducanu-jelena-ostapenko-intl-spt.json',
#  'emma-raducanu-wrist-ankle-surgery-spt-intl.json',
#  'emmanuel-macron-fast-facts.json',
#  'emmanuel-macron-russia-flag-paris-2024-spt-intl.json',
#  'empire-state-building-green-philadelphia-eagles-spt-intl.json',
#  'endangered-toad-stops-play-open-championship-spt-intl.json',
#  'england-argentina-china-womens-world-cup-spt-intl.json',
#  'england-australia-nameless-shirts-alzheimers-spt-intl.json',
#  'england-brazil-finalissima-spt-intl.json',
#  'england-colombia-womens-world-cup-2023-spt-intl.json',
#  'england-france-womens-six-nations-world-record-crowd-spt-intl.json',
#  'england-haiti-womens-world-cup-2023-spt-intl.json',
#  'england-lauren-james-suspension-wwc-spt-intl-hnk.json',
#  'england-leah-williamson-injury-world-cup-spt-intl.json',
#  'england-nigeria-australia-denmark-womens-world-cup-2023-spt-intl.json',
#  'england-womens-world-cup-australia-reaction-spt-intl.json',
#  'enrico-letta-fast-facts.json',
#  'enrique-llopis-fall-european-indoor-championships-spt-intl.json',
#  'enzo-fernandez-chelsea-benfica-transfer-spt-intl.json',
#  'epsom-derby-arrests-protests-spt-intl.json',
#  'erchana-murray-bartlett-150-marathons-australia-intl-hnk.json',
#  'erdogan-earthquake-election-intl.json',
#  'erdogan-turkey-nato-eu-sweden-intl.json',
#  'eric-lira-pleads-guilty-performance-enhancing-drugs-olympic-spt-intl.json',
#  'eric-marc-staal-nhl-pride-night.json',
#  'erin-kennedy-cancer-recovery-spt-intl.json',
#  'erling-haaland-50th-goal-spt-intl.json',
#  'erling-haaland-manchester-city-bayern-munich-record-spt-intl.json',
#  'erling-haaland-manchester-city-bournemouth-records-spt-intl.json',
#  'erling-haaland-manchester-city-champions-league-intl-spt.json',
#  'erling-haaland-manchester-city-records-spt-intl.json',
#  'erling-haaland-premier-league-record-intl-hnk.json',
#  'erling-haaland-profile-manchester-city-spt-intl.json',
#  'erling-haaland-records-southampton-manchester-city-spt-intl.json',
#  'esports-asian-games-military-exemption-medals-hnk-spt-intl.json',
#  'estonia-nato-tank-exercises-intl-cmd.json',
#  'estonia-same-sex-marriage-legal-intl.json',
#  'ethan-boyes-death-cycling.json',
#  'ethnic-armenians-could-leave-nagorno-karabakh-intl.json',
#  'eton-harrow-lords-cricket-spt-intl.json',
#  'eu-fossil-fuels-cop28-climate-intl.json',
#  'eu-irc-afghans-neglect-intl.json',
#  'eu-nature-restoration-law-climate-intl.json',
#  'eu-poland-visa-fraud-allegations-intl.json',
#  'eubanks-medvedev-tennis-wimbledon-spt-intl.json',
#  'eugene-exploding-whales-baseball-intl-spt.json',
#  'europe-drought-lake-montbel-france-climate-intl.json',
#  'europe-extreme-heat-january-climate-intl.json',
#  'europe-heat-records-climate-intl.json',
#  'europe-migration-chaos-boat-arrivals-intl.json',
#  'europe-populism-far-right-extreme-intl-cmd.json',
#  'europe-putin-warm-winter-intl.json',
#  'europe-state-of-climate-heat-drought-intl.json',
#  'europe-weather-second-heatwave-charon-climate-intl.json',
#  'europe-winter-drought-rivers-climate-intl.json',
#  'european-debt-crisis-fast-facts.json',
#  'european-energy-security-russia-ukraine-china-cmd-intl.json',
#  'european-super-league-organizers-revamped-competition-spt-intl.json',
#  'european-tanks-to-ukraine-intl.json',
#  'eurovision-security-liverpool-intl-cmd.json',
#  'eurovision-song-contest-2023-grand-final-cmd-gbr-intl.json',
#  'eurovision-song-contest-2023-winner-intl.json',
#  'eurovision-song-contest-explainer-2023-intl.json',
#  'evan-gershkovich-appeals-arrest-russia-intl.json',
#  'evan-gershkovich-appeals-detention-russia-intl.json',
#  'evan-gershkovich-detention-intl.json',
#  'evan-gershkovich-pre-trial-detention-intl.json',
#  'evan-gershkovich-us-russia-analysis-intl.json',
#  'evans-chebet-wins-boston-marathon-spt-intl.json',
#  'everton-safety-threat-spt-intl.json',
#  'ex-british-embassy-spy-sentenced-intl-gbr.json',
#  'extinction-rebellion-golf-course-spain-climate-intl.json',
#  'extinction-rebellion-netherlands-arrests-intl.json',
#  'extinction-rebellion-quits-disruptive-protests-climate-intl.json',
#  'f-16-jets-ukraine-analysis-intl-hnk-ml.json',
#  'fabian-marozsan-carlos-alcaraz-rome-masters-spt-intl.json',
#  'faith-kipyegon-1500m-world-record-spt-intl.json',
#  'faith-kipyegon-women-world-record-spt-intl.json',
#  'far-left-students-jail-germany-lina-e-intl.json',
#  'farmers-land-mines-clearance-ukraine-russia-invasion-intl-hnk.json',
#  'fatal-fire-brno-czech-republic.json',
#  'fc-barcelona-corruption-charges-referees-payments-spt-intl.json',
#  'fc-barcelona-under-investigation-for-payments-spt-intl.json',
#  'fc-mariupol-relocate-brazil-ukraine-spt-intl.json',
#  'femke-bol-world-record-400-meter-spt-intl.json',
#  'fencers-urge-ioc-to-uphold-russia-and-belarus-sanctions-spt-intl.json',
#  'fencing-world-cup-canceled-russia-belarus-spt-intl.json',
#  'fernando-alonso-formula-one-aston-martin-spt-intl.json',
#  'fernando-alonso-saudi-arabian-grand-prix-podium-fia-spt-intl.json',
#  'fia-freedom-of-speech-human-rights-intl-spt.json',
#  'fifa-best-awards-lionel-messi-alexia-putellas-spt-intl.json',
#  'fifa-luis-rubiales-suspension-spt-intl.json',
#  'fifa-removes-indonesia-hosts-u20-world-cup-intl-hnk-spt.json',
#  'fifa-womens-world-cup-saudi-arabia-spt-intl.json',
#  'finger-elysee-paris-intl.json',
#  'finland-finance-minister-racist-comments-intl.json',
#  'finland-joins-nato-intl.json',
#  'fire-cargo-ship-dutch-coast-intl.json',
#  'fire-moscow-ministry-defense-intl.json',
#  'fisherman-cheating-sentenced-jail-spt-intl.json',
#  'floods-ruin-crops-livestock-italy-intl.json',
#  'florida-panthers-advance-stanley-cup.json',
#  'florida-panthers-boston-bruins-nhl-spt-intl.json',
#  'football-transfer-spend-2022-spt-intl.json',
#  'former-soldier-charged-war-crime-afghanistan-intl-hnk.json',
#  'former-wagner-fighters-bakhmut-ukraine-intl.json',
#  'formula-equal-f1-motorsport-spt-intl.json',
#  'formula-one-2023-season-preview-spt-intl.json',
#  'formula-one-miami-grand-prix-2023-spt-intl.json',
#  'foster-moreau-nfl-hodgkin-lymphoma-diagnosis-spt-intl.json',
#  'four-arrested-for-vinicius-jr-effigy-spt-intl.json',
#  'fowler-clark-third-round-us-open-spt-intl.json',
#  'fowler-schauffele-us-open-first-round-spt-intl.json',
#  'fowler-schauffele-us-open-round-record-spt-intl.json',
#  'france-abaya-ban-scli-intl.json',
#  'france-abayas-schools-ban-intl.json',
#  'france-alps-missing-toddler-search-intl.json',
#  'france-annecy-knife-attack-charges-intl.json',
#  'france-annecy-knife-attack-intl.json',
#  'france-ban-pro-palestinian-intl.json',
#  'france-brazil-jamaica-panama-sweden-italy-womens-world-cup-spt-intl.json',
#  'france-bruno-le-maire-erotica-intl.json',
#  'france-end-military-presence-niger-intl.json',
#  'france-evacuates-citizens-sudan-hnk-intl.json',
#  'france-fire-holiday-home-disabled-people-intl.json',
#  'france-fireworks-ban-bastille-day-intl.json',
#  'france-free-condoms-intl-scli.json',
#  'france-fundraiser-nahel-protests-intl.json',
#  'france-macron-abaya-ban-intl.json',
#  'france-mayor-protests-march-intl.json',
#  'france-oldest-person-world-dies-intl.json',
#  'france-pension-protests-explainer-intl.json',
#  'france-pension-reform-intl.json',
#  'france-pension-reform-protests-biarritz-airport-intl.json',
#  'france-pension-reform-ruling-intl.json',
#  'france-pension-reform-strikes-intl.json',
#  'france-protests-pensions-lvmh-intl.json',
#  'france-retirement-protests-macron-court-intl.json',
#  'france-sarkozy-corruption-appeal-intl.json',
#  'france-student-teacher-stabbing-intl.json',
#  'france-teenager-shot-police-traffic-stop-nanterre-intl-hnk.json',
#  'france-uk-germany-security-measures-hamas-attack-intl.json',
#  'france-wine-crisis-intl.json',
#  'francis-ngannou-ufc-contract-spt-intl.json',
#  'francois-hollande---fast-facts.json',
#  'frank-vogel-phoenix-suns-spt-intl.json',
#  'fred-couples-oldest-player-cut-the-masters-spt-intl.json',
#  'french-alps-avalanche-intl.json',
#  'french-ambassador-niger-hostage-intl.json',
#  'french-court-rejects-abaya-appeal-intl.json',
#  'french-football-federation-resignations-le-graet-spt-intl.json',
#  'french-government-ban-climate-group-intl.json',
#  'french-minister-playboy-cover-intl.json',
#  'french-open-fast-facts.json',
#  'french-open-final-preview-djokovic-ruud-spt-intl.json',
#  'french-open-marta-kostyuk-aryna-sabalenka-spt-intl.json',
#  'french-open-preview-tennis-spt-intl.json',
#  'french-pension-reforms-explainer-intl-cmd.json',
#  'fuel-tank-sevastopol-crimea-hnk-intl.json',
#  'fulham-manchester-united-fa-cup-spt-intl.json',
#  'full-swing-golf-netflix-series-spt-intl.json',
#  'full-swing-netflix-golf-series-psychology-spc-spt-intl.json',
#  'furman-shock-virginia-march-madness-spt-intl.json',
#  'fuzz-caan-high-jump-coach-suspension-spt-intl.json',
#  'gare-du-nord-knife-attack-intl-hnk.json',
#  'gareth-bale-pebble-beach-cart-shot-spt-intl.json',
#  'gareth-bale-pebble-beach-pro-am-pga-spt-intl.json',
#  'gareth-bale-retirement-spt-intl.json',
#  'gary-lineker-bbc-impartiality-row-boycott-spt-intl.json',
#  'gary-lineker-match-of-the-day-spt-intl.json',
#  'gary-lineker-resumes-bbc-impartiality-row-spt-intl.json',
#  'gary-mckee-marathon-running-spt-intl.json',
#  'georgia-bill-protests-withdrawn-intl-hnk.json',
#  'georgia-bulldogs-tcu-horned-frogs-national-championship-spt-intl.json',
#  'georgia-explainer-intl.json',
#  'georgia-foreign-agents-bill-intl.json',
#  'georgia-protests-wednesday-intl.json',
#  'georgia-revokes-foreign-influence-bill-intl.json',
#  'georgia-tcu-national-championship-how-to-watch-spt-intl.json',
#  'german-climber-remains-glacier-climate-scli-intl-scn.json',
#  'german-police-doppelganger-murder-intl.json',
#  'german-police-raid-last-generation-climate-activists-intl.json',
#  'german-tanks-ukraine-intl.json',
#  'germany-98-year-old-nazi-guard-intl.json',
#  'germany-aid-package-ukraine-intl-ukr.json',
#  'germany-berlin-lioness-escape-intl-hnk.json',
#  'germany-border-controls-migration-debate-intl.json',
#  'germany-cdu-identity-crisis-intl.json',
#  'germany-giessen-protest-eritrea-intl.json',
#  'germany-isis-member-conviction-scli-intl.json',
#  'germany-leopard-2-tank-ukraine-explainer-intl.json',
#  'germany-leopard-2-tanks-ukraine-announcement-intl.json',
#  'germany-leopard-tanks-ukraine-impact-explainer-intl.json',
#  'germany-mayor-syrian-refugee-intl.json',
#  'germany-mood-leopard-ukraine-intl.json',
#  'germany-national-russian-spy-suspect-intl.json',
#  'germany-nazi-lgbt-victims-intl.json',
#  'germany-nuclear-phase-out-climate-intl.json',
#  'germany-reichsbuerger-movement-explainer-intl.json',
#  'germany-russia-us-relations-intl-cmd.json',
#  'germany-state-elections-bavaria-hesse-intl.json',
#  'germany-suspected-russian-exile-poisoning-intl.json',
#  'germany-tanks-ukraine-intl.json',
#  'germany-terror-iranian-suspect-intl-hnk.json',
#  'germany-top-heavy-metal-festival-intl.json',
#  'germany-violence-against-women-study-intl.json',
#  'germany-winterberg-tunnel-wwi-soldiers-intl-scli.json',
#  'gerry-adams-fast-facts.json',
#  'gershkovich-russia-wsj-charged-intl.json',
#  'gervonta-davis-ryan-garcia-fight-spt-intl.json',
#  'ghislaine-maxwell-jail-interview-gbr-intl.json',
#  'gianluca-vialli-death-spt-intl.json',
#  'gianni-infantino-fifa-president-reelection-intl-spt.json',
#  'gianni-infantino-fifa-women-world-cup-2023-spt-intl.json',
#  'gianni-infantino-italy-racism-football-spt-intl.json',
#  'gianni-infantino-wwc-2023-new-zealand-spt-intl.json',
#  'gil-brandt-dallas-cowboys-dies-91-spt-intl.json',
#  'giulia-dragoni-italy-argentina-womens-world-cup-spt-intl.json',
#  'glenda-jackson-obituary-gbr-intl.json',
#  'gold-coast-australia-helicopter-crash-intl-hnk.json',
#  'golden-state-warriors-sacramento-kings-game-4-spt-intl.json',
#  'golf-digest-open-launch-spt-intl.json',
#  'golf-hitting-distance-proposals-usga-spt-intl.json',
#  'golf-nicknames-gallery-spt-intl.json',
#  'golf-outrageous-fashion-spt-spc-intl.json',
#  'golf-preview-2023-spc-spt-intl.json',
#  'good-friday-agreement-explained-intl-cmd-gbr.json',
#  'good-friday-agreement-peace-baby-intl-gbr.json',
#  'grand-national-animals-rights-protests-spt-intl.json',
#  'grand-national-protests-spt-intl.json',
#  'grant-wahl-celine-gounder-amanpour-interview-spt-intl.json',
#  'great-barrier-reef-coal-mine-environment-climate-intl.json',
#  'great-britain-world-baseball-classic-spt-intl.json',
#  'greece-drops-espionage-charges-migrant-workers-intl-hnk.json',
#  'greece-europe-extreme-weather-climate-intl.json',
#  'greece-flooding-climate-intl.json',
#  'greece-floods-storm-rescue-climate-intl.json',
#  'greece-general-election-no-majority-intl.json',
#  'greece-migrant-boat-disaster-investigation-intl-cmd.json',
#  'greece-new-elections-judge-caretaker-intl.json',
#  'greece-record-breaking-heat-wave-climate-intl.json',
#  'greece-storm-elias-intl-scn-hnk.json',
#  'greece-train-crash-larissa-intl-hnk.json',
#  'greece-train-crash-larissa-protests-intl.json',
#  'greece-wildfire-athens-intl-climate-cmd.json',
#  'greece-wildfires-arson-arrests-intl.json',
#  'greece-wildfires-france-heat-climate-change-intl.json',
#  'greek-prime-minister-apologizes-intl.json',
#  'greek-prime-minister-railway-deficiencies-intl.json',
#  'gregg-berhalter-danielle-reyna-us-soccer-spt-intl.json',
#  'gregg-berhalter-returns-usmnt-coach-spt-intl.json',
#  'gregg-berhalter-us-soccer-investigation.json',
#  'greta-thunberg-arrest-london-climate-intl.json',
#  'greta-thunberg-charged-london-climate-intl-gbr.json',
#  'greta-thunberg-charged-sweden-climate-intl.json',
#  'greta-thunberg-fine-sweden-climate-intl.json',
#  'greta-thunberg-released-germany-climate-intl.json',
#  'greta-thunberg-wind-farm-norway-sami-climate-intl.json',
#  'guilty-plea-queen-elizabeth-christmas-2021-intl.json',
#  'hadwin-security-tackle-taylor-canadian-open-spt-intl.json',
#  'haiti-womens-world-cup-legacy-spt-intl-hnk.json',
#  'hamburg-germany-shooting-intl.json',
#  'hamburg-ironman-death-spt-intl.json',
#  'hamburg-warehouse-fire-intl.json',
#  'harry-kane-bayern-munich-debut-german-super-cup-intl-hnk.json',
#  'harry-meghan-king-charles-coronation-intl-hnk.json',
#  'hayden-buckley-hole-in-one-players-championship-spt-intl.json',
#  'head-injury-suicide-female-athletes-intl-spt-cmd.json',
#  'helen-maroulis-concussion-wrestling-spt-intl.json',
#  'helicopter-crash-ukraine-intl.json',
#  'henry-blackburn-death-threats-spt.json',
#  'hermoso-rubiales-kiss-statement-wwc-spt-intl-hnk.json',
#  'hiroshima-bakhmut-zelensky-g7-intl.json',
#  'holding-call-super-bowl-lvii-chiefs-eagles-spt-intl.json',
#  'holger-rune-beats-novak-djokovic-italian-open-spt-intl.json',
#  'hornussen-switzerland-golf-baseball-farmers-spt-intl.json',
#  'horse-deaths-kentucky-derby-spt.json',
#  'horse-dies-belmont-park-injury-spt-intl.json',
#  'horse-racing-deaths-emergency-summit.json',
#  'houses-of-parliament-great-britain-fast-facts.json',
#  'how-manchester-city-won-the-premier-league-once-again-spt-intl.json',
#  'how-to-watch-uswnt-netherlands-womens-world-cup-spt-intl.json',
#  'how-watch-coronation-us-time-start-intl-scli-gbr.json',
#  'howard-university-swimming-diving-champions.json',
#  'hroza-strike-residents-ukraine-intl.json',
#  'human-rights-watch-2023-report-intl.json',
#  'hungary-icc-warrant-putin-intl.json',
#  'iain-ward-king-of-chemo-us-cycle-spt-intl.json',
#  'icc-russia-war-crimes-charges-intl.json',
#  'icc-war-crimes-russia-ukraine-intl.json',
#  'iceland-maternity-pay-olympique-lyonnais-spt-intl.json',
#  'iceland-volcano-erupts-litli-hrtur-intl-hnk.json',
#  'iceland-women-strike-scli-intl.json',
#  'iga-swiatek-australian-open-eliminated-spt-intl-hnk.json',
#  'iga-swiatek-beats-kaja-juvan-us-open-spt-intl.json',
#  'iga-swiatek-karolina-muchova-french-open-final-spt-intl.json',
#  'iga-swiatek-loses-jelena-ostapenko-us-open-spt-intl.json',
#  'iga-swiatek-russia-belarus-tennis-wimbledon-spt-intl.json',
#  'iga-swiatek-zheng-qinwen-tennis-spt-intl.json',
#  'igor-girkin-arrest-russia-intl.json',
#  'ilia-malinin-us-figure-skating-championships-spt-intl.json',
#  'ime-udoka-houston-rockets-head-coach-spt-intl.json',
#  'ime-udoka-houston-rockets-presentation-spt-intl.json',
#  'india-motogp-spt-intl.json',
#  'indian-wrestlers-sexual-harassment-inquiry-protest-spt-intl.json',
#  'indiana-pacers-nba-investigation-spt-intl.json',
#  'indianapolis-colts-isaiah-rodgers-gambling-nfl-spt-intl.json',
#  'indy-500-preview-katherine-legge-spt-intl.json',
#  'inter-ac-milan-champions-league-semifinal-second-leg-spt-intl.json',
#  'ioc-russia-belarus-ban-spt-intl.json',
#  'ioc-russian-belarusian-athletes-olympic-games-spt-intl.json',
#  'iowa-football-gambling-charges-spt.json',
#  'iowa-lsu-march-madness-championship-game-preview-spt-intl.json',
#  'iowa-south-carolina-caitlin-clark-march-madness-spt-intl.json',
#  'iowa-state-football-gambling-investigation.json',
#  'iran-paris-dissidents-mime-intl.json',
#  'iran-russia-shipments-caspian-sea-intl-cmd.json',
#  'iranian-chess-referee-shohreh-bayat-russia-spt-intl.json',
#  'iranian-chess-sara-khadem-spanish-prime-minister-spt-intl.json',
#  'iraq-gulf-cup-comeback-mime-intl.json',
#  'ireland-abortion-referendum-5-years-intl-cmd.json',
#  ...]

# %%
articles = dict()

# %%
for filename in ldir:
    with open(f'nouns/{filename}') as f:
        articles[filename[:-5]] = json.load(f)

# %%
articles
# Out:
# {'10-year-old-ukraine-boy-asleep-when-russia-drone-strike-intl-hnk': ['boy',
#   'strike',
#   'city',
#   'kharkiv',
#   'friday',
#   'picture',
#   'show',
#   'body',
#   'defense',
#   'show',
#   'body',
#   'blanket',
#   'dust',
#   'body',
#   'morning',
#   'kharkiv',
#   'boy',
#   'ministry',
#   'iskander',
#   'missile',
#   'reach',
#   'kharkiv',
#   'border',
#   'city',
#   'grandmother',
#   'brother',
#   'state',
#   'administration',
#   'chief',
#   'president',
#   'volodymyr',
#   'address',
#   'brother',
#   'russia',
#   'result',
#   'morning',
#   'october',
#   'severity',
#   'prosecutor',
#   'attack',
#   'kharkiv',
#   'day',
#   'missile',
#   'strike',
#   'village',
#   'hroza',
#   'thursday',
#   'child',
#   'hroza',
#   'village',
#   'region',
#   'grocery',
#   'store',
#   'cafe',
#   'lady',
#   'olena',
#   'attack',
#   'cruel',
#   'sense',
#   'war',
#   'federation',
#   'minister',
#   'dmitro',
#   'kuleba',
#   'support',
#   'war',
#   'russia',
#   'strike'],
#  '1000-russian-tanks-destroyed-ukraine-war-intl-hnk-ml': ['russia',
#   'tank',
#   'fleet',
#   'war',
#   'information',
#   'monitoring',
#   'group',
#   'oryx',
#   'source',
#   'intelligence',
#   'website',
#   'evidence',
#   'equipment',
#   'invasion',
#   'group',
#   'week',
#   'tank',
#   'toll',
#   'jakub',
#   'janovsky',
#   'analyst',
#   'toll',
#   'war',
#   'chance',
#   'russia',
#   'half',
#   'janovsky',
#   'focus',
#   'invasion',
#   'ukraine',
#   'territory',
#   'tank',
#   'fight',
#   'count',
#   'cover',
#   'way',
#   'month',
#   'germany',
#   'technology',
#   'battle',
#   'fight',
#   'armor',
#   'war',
#   'design',
#   'flaw',
#   'round',
#   'ammunition',
#   'blast',
#   'armor',
#   'war',
#   'storage',
#   'sent',
#   'front',
#   'janovsky',
#   'war',
#   'paper',
#   'russia',
#   'reactivate',
#   'action',
#   'moscow',
#   'tank',
#   'force',
#   'janovsky',
#   'replacement',
#   'amount',
#   'term',
#   'fraction',
#   'figure',
#   'equipment',
#   'infantry',
#   'fighting',
#   'equipment',
#   'oryx'],
#  '2015-paris-terror-attacks-fast-facts': ['look',
#   'terror',
#   'magazine',
#   'charlie',
#   'hebdo',
#   'grocery',
#   'store',
#   'paris',
#   'suburb',
#   'december',
#   'court',
#   'islamist',
#   'magazine',
#   'goal',
#   'religion',
#   'publication',
#   'death',
#   'president',
#   'title',
#   'hebdomadaire',
#   'magazine',
#   'publication',
#   'lack',
#   'hebdo',
#   'newspaper',
#   'president',
#   'decision',
#   'gasoline',
#   'bomb',
#   'caricature',
#   'prophet',
#   'cherif',
#   'kouachi',
#   'france',
#   'standoff',
#   'police',
#   'cherif',
#   'affiliate',
#   'bfmtv',
#   'peninsula',
#   'aqap',
#   'time',
#   'muslim',
#   'face',
#   'aqap',
#   'france',
#   'time',
#   'kouachi',
#   'amedy',
#   'coulibaly',
#   'france',
#   'serving',
#   'time',
#   'subway',
#   'time',
#   'cherif',
#   'kouachi',
#   'investigation',
#   'plot',
#   'evidence',
#   'indict',
#   'coulibaly',
#   'affiliate',
#   'bfmtv',
#   'phone',
#   'boumeddiene',
#   'france',
#   'girlfriend',
#   'part',
#   'woman',
#   'kosher',
#   'grocery',
#   'store',
#   'ministry',
#   'source',
#   'boumeddiene',
#   'airport',
#   'flight',
#   'madrid',
#   'return',
#   'ticket',
#   'return',
#   'flight',
#   'istanbul',
#   'source',
#   'security',
#   'france',
#   'course',
#   'reach',
#   'paris',
#   'prosecutor',
#   'francois',
#   'cherif',
#   'wife',
#   'phone',
#   'boumeddiene',
#   'absentia',
#   'financing',
#   'terrorism',
#   'terrorist',
#   'way',
#   'charlie',
#   'hebdo',
#   'prophet',
#   'akbar',
#   'magazine',
#   'maintenance',
#   'worker',
#   'police',
#   'officer',
#   'building',
#   'police',
#   'officer',
#   'street',
#   'day',
#   'phrase',
#   'suis',
#   'police',
#   'name',
#   'area',
#   'northeast',
#   'paris',
#   'gunman',
#   'hebdo',
#   'attack',
#   'bulletproof',
#   'vest',
#   'officer',
#   'paris',
#   'suburb',
#   'food',
#   'gas',
#   'gas',
#   'station',
#   'gas',
#   'station',
#   'law',
#   'enforcement',
#   'official',
#   'list',
#   'evening',
#   'eiffel',
#   'tower',
#   'briefly',
#   'remembrance',
#   'morning',
#   'police',
#   'building',
#   'paris',
#   'afternoon',
#   'grocery',
#   'store',
#   'paris',
#   'suburb',
#   'porte',
#   'police',
#   'attack',
#   'accomplice',
#   'police',
#   'launch',
#   'assault',
#   'operation',
#   'coulibaly',
#   'grocery',
#   'coulibaly',
#   'france',
#   'paris',
#   'world',
#   'president',
#   'francois',
#   'hollande',
#   'chancellor',
#   'angela',
#   'merkel',
#   'minister',
#   'benjamin',
#   'netanyahu',
#   'authority',
#   'president',
#   'minister',
#   'david',
#   'cameron',
#   'march',
#   'hollande',
#   'order',
#   'légion',
#   'honor',
#   'police',
#   'ceremony',
#   'prefecture',
#   'bulgaria',
#   'arrest',
#   'warrant',
#   'connection',
#   'charlie',
#   'hebdo',
#   'edition',
#   'magazine',
#   'cartoon',
#   'muslim',
#   'prophet',
#   'cover',
#   'sign',
#   'suis',
#   'aqap',
#   'responsibility',
#   'operation',
#   'hebdo'],
#  '2023-march-madness-mens-final-four-preview-spt-intl': ['kind',
#   'season',
#   'culmination',
#   'college',
#   'basketball',
#   'season',
#   'march',
#   'madness',
#   'corner',
#   'round',
#   'time',
#   'team',
#   'tournament',
#   'florida',
#   'university',
#   'fau',
#   'diego',
#   'state',
#   'miami',
#   'play',
#   'university',
#   'none',
#   'time',
#   'fau',
#   'story',
#   'nation',
#   'tournament',
#   'win',
#   'fau',
#   'basket',
#   'round',
#   'memphis',
#   'rolling',
#   'dickinson',
#   'tennessee',
#   'kansas',
#   'state',
#   'fifth',
#   'team',
#   'tournament',
#   'guard',
#   'alijah',
#   'martin',
#   'feel',
#   'cinderella',
#   'feel',
#   'fau',
#   'face',
#   'diego',
#   'state',
#   'appearance',
#   'victory',
#   'seed',
#   'creighton',
#   'sunday',
#   'foul',
#   'call',
#   'game',
#   'diego',
#   'darrion',
#   'trammell',
#   'hand',
#   'hip',
#   'trammell',
#   'aztecs',
#   'dream',
#   'run',
#   'diego',
#   'state',
#   'seed',
#   'alabama',
#   'round',
#   'game',
#   'seed',
#   'team',
#   'defense',
#   'creighton',
#   'half',
#   'step',
#   'something',
#   'minute',
#   'diego',
#   'state',
#   'coach',
#   'brian',
#   'dutcher',
#   'side',
#   'bracket',
#   'miami',
#   'team',
#   'year',
#   'time',
#   'jim',
#   'larrañaga',
#   'year',
#   'head',
#   'coach',
#   'form',
#   'suffering',
#   'home',
#   'loss',
#   'florida',
#   'tournament',
#   'margin',
#   'miami',
#   'seed',
#   'texas',
#   'foe',
#   'run',
#   'victory',
#   'place',
#   'larrañaga',
#   'positivity',
#   'year',
#   'run',
#   'exhilaration',
#   'attitude',
#   'love',
#   'goal',
#   'set',
#   'season',
#   'day',
#   'practice',
#   'seed',
#   'run',
#   'madness',
#   'round',
#   'tipoff',
#   'team',
#   'margin',
#   'seed',
#   'gonzaga',
#   'victory',
#   'margin',
#   'team',
#   'competition',
#   'title',
#   'name',
#   'pressure',
#   'experience',
#   'championship',
#   'trophy',
#   'time',
#   'expectation',
#   'sanogo',
#   'point',
#   'something',
#   'time',
#   'basketball',
#   'show'],
#  '2023-nfl-draft-how-to-watch-preview-spt-intl': ['spring',
#   'draft',
#   'season',
#   'joy',
#   'edition',
#   'order',
#   'life',
#   'carolina',
#   'ambition',
#   'trading',
#   'pick',
#   'draft',
#   'receiver',
#   'moore',
#   'ability',
#   'look',
#   'everything',
#   'need',
#   'nfl',
#   'draft',
#   'nfl',
#   'draft',
#   'year',
#   'kansas',
#   'city',
#   'missouri',
#   'home',
#   'champion',
#   'city',
#   'tune',
#   'watch',
#   'australia',
#   'espn',
#   'germany',
#   'rtl',
#   'mexico',
#   'fox',
#   'africa',
#   'game',
#   'pass',
#   'nfl',
#   'network',
#   'abc',
#   'list',
#   'watch',
#   'draft',
#   'level',
#   'quarterback',
#   'atop',
#   'draft',
#   'bryce',
#   'caller',
#   'california',
#   'native',
#   'player',
#   'quarterback',
#   'famer',
#   'analyst',
#   'lance',
#   'reader',
#   'demeanor',
#   'field',
#   'tape',
#   'knock',
#   'draft',
#   'build',
#   'ability',
#   'contact',
#   'sustain',
#   'talent',
#   'cam',
#   'decline',
#   'fraction',
#   'tape',
#   'lead',
#   'placement',
#   'predict',
#   'order',
#   'snap',
#   'houston',
#   'number',
#   'franchise',
#   'quarterback',
#   'fill',
#   'levis',
#   'anthony',
#   'richardson',
#   'quarterback',
#   'class',
#   'game',
#   'selection',
#   'hand',
#   'floor',
#   'richardson',
#   'star',
#   'ceiling',
#   'quarterback',
#   'talent',
#   'side',
#   'ball',
#   'headline',
#   'player',
#   'university',
#   'georgia',
#   'standout',
#   'jalen',
#   'carter',
#   'talent',
#   'projection',
#   'carter',
#   'step',
#   'talent',
#   'bowl',
#   'potential',
#   'tackle',
#   'draft',
#   'stock',
#   'march',
#   'role',
#   'crash',
#   'team',
#   'teammate',
#   'devin',
#   'willock',
#   'football',
#   'team',
#   'staff',
#   'member',
#   'chandler',
#   'lecroy',
#   'crash',
#   'team',
#   'campus',
#   'celebrate',
#   'carter',
#   'county',
#   'jail',
#   'march',
#   'lecroy',
#   'ford',
#   'suv',
#   'campus',
#   'willock',
#   'football',
#   'program',
#   'vehicle',
#   'police',
#   'suv',
#   'road',
#   'power',
#   'county',
#   'police',
#   'carter',
#   'vehicle',
#   'lecroy',
#   'pleas',
#   'serve',
#   'probation',
#   'fine',
#   'community',
#   'service',
#   'defensive',
#   'driving',
#   'teams',
#   'prospect',
#   'edge',
#   'rusher',
#   'anderson',
#   'alabama',
#   'combination',
#   'speed',
#   'strength',
#   'ability',
#   'line',
#   'pressure',
#   'backfield',
#   'plenty',
#   'gonzalez',
#   'branch',
#   'devon',
#   'witherspoon',
#   'penn',
#   'joey',
#   'porter',
#   'success',
#   'particular',
#   'player',
#   'season',
#   'watch',
#   'end',
#   'brock',
#   'purdy',
#   'pick',
#   'draft',
#   'opportunity',
#   'start',
#   'team',
#   'super',
#   'bowl',
#   'season',
#   'season',
#   'philadelphia',
#   'injury',
#   'defeat',
#   'consideration',
#   'starter',
#   'season',
#   'rise',
#   'moniker',
#   'pick',
#   'rule',
#   'eye',
#   'houston',
#   'keep',
#   'tabs',
#   'journey',
#   'order',
#   'draft',
#   'carolina',
#   'houston',
#   'indianapolis',
#   'philadelphia',
#   'tennessee',
#   'houston',
#   'york',
#   'england',
#   'bay',
#   'washington',
#   'pittsburgh',
#   'seahawks',
#   'los',
#   'baltimore',
#   'jacksonville',
#   'york',
#   'buffalo',
#   'philadelphia',
#   'city'],
#  '2023-womens-world-cup-media-rights-infantino-spt-intl': ['president',
#   'gianni',
#   'infantino',
#   'world',
#   'cup',
#   'broadcast',
#   'infantino',
#   'panel',
#   'discussion',
#   'world',
#   'trade',
#   'organization',
#   'headquarters',
#   'geneva',
#   'spain',
#   'italy',
#   'france',
#   'obligation',
#   'undersell',
#   'world',
#   'therefore',
#   'fair',
#   'football',
#   'broadcast',
#   'fifa',
#   'world',
#   'cup',
#   'infantino',
#   'world',
#   'cup',
#   'july',
#   'infantino',
#   'price',
#   'tournament',
#   'fifa',
#   'world',
#   'football',
#   'body',
#   'statement',
#   'infantino',
#   'world',
#   'cup',
#   'fifa',
#   'world',
#   'face',
#   'world',
#   'cup',
#   'football',
#   'promote',
#   'duty',
#   'promote',
#   'sport',
#   'infantino',
#   'world',
#   'world',
#   'cup',
#   'event',
#   'world',
#   'cup',
#   'world',
#   'world',
#   'march',
#   'infantino',
#   'money',
#   'fifa',
#   'world',
#   'cup',
#   'portion',
#   'payment',
#   'football',
#   'development',
#   'portion',
#   'world',
#   'cup',
#   'money',
#   'figure',
#   'infantino',
#   'taking',
#   'money',
#   'world',
#   'cup',
#   'qatar',
#   'year'],
#  '70-shot-rally-kubler-khachanov-australian-open-spt-intl': ['sent',
#   'rapture',
#   'home',
#   'favorite',
#   'jason',
#   'seed',
#   'john',
#   'cain',
#   'kubler',
#   'opportunity',
#   'break',
#   'exchange',
#   'mistake',
#   'neither',
#   'winner',
#   'rally',
#   'tension',
#   'inch',
#   'rally',
#   'backhand',
#   'kubler',
#   'win',
#   'point',
#   'send',
#   'crowd',
#   'rally',
#   'kubler',
#   'level',
#   'match',
#   'clash',
#   'semifinalist',
#   'rally',
#   'gaël',
#   'court',
#   'round',
#   'match',
#   'place',
#   'jean',
#   'hepner',
#   'nelson',
#   'rally',
#   'richmond',
#   'virginia',
#   'world',
#   'record',
#   'tennis',
#   'world',
#   'tennis',
#   'rally',
#   'simone',
#   'frediani',
#   'daniele',
#   'pecci',
#   'june',
#   'attempt',
#   'record',
#   'attempt',
#   'water',
#   'day'],
#  'aaron-judge-catch-yankees-jake-burger-spt-intl': ['aaron',
#   'judge',
#   'stranger',
#   'saturday',
#   'list',
#   'york',
#   'victory',
#   'los',
#   'martinez',
#   'drive',
#   'ball',
#   'hand',
#   'ball',
#   'momentum',
#   'door',
#   'bullpen',
#   'judge',
#   'throw',
#   'fence',
#   'judge',
#   'part',
#   'wall',
#   'wall',
#   'mlb',
#   'website',
#   'judge',
#   'play',
#   'probability',
#   'catch',
#   'list',
#   'spot',
#   'manager',
#   'boone',
#   'catch',
#   'heart',
#   'fence',
#   'judge',
#   'briefly',
#   'door',
#   'host',
#   'okay',
#   'judge',
#   'sunday',
#   'judge',
#   'series',
#   'finale',
#   'toe',
#   'right',
#   'york',
#   'mri',
#   'judge',
#   'today',
#   'monday',
#   'bit',
#   'rest',
#   'day',
#   'day',
#   'jake',
#   'burger',
#   'slam',
#   'chicago',
#   'win',
#   'detroit',
#   'game',
#   'end',
#   'benintendi',
#   'yoan',
#   'moncada',
#   'tim',
#   'anderson',
#   'hit',
#   'field',
#   'bat',
#   'sure',
#   'bat',
#   'burger',
#   'wall',
#   'victory',
#   'adversity',
#   'come',
#   'burger',
#   'play',
#   'mound',
#   'hendriks',
#   'win',
#   'time',
#   'diagnosis',
#   'hendriks',
#   'moment',
#   'fact',
#   'cancer',
#   'thing',
#   'hendriks',
#   'thing',
#   'field'],
#  'aaron-judge-opening-day-home-run-giants-spt-intl': ['aaron',
#   'judge',
#   'ball',
#   'baseball',
#   'day',
#   'season',
#   'home',
#   'run',
#   'record',
#   'season',
#   'pitch',
#   'san',
#   'francisco',
#   'webb',
#   'stadium',
#   'wall',
#   'thursday',
#   'homer',
#   'season',
#   'victory',
#   'hit',
#   'judge',
#   'home',
#   'plate',
#   'family',
#   'roar',
#   'crowd',
#   'soak',
#   'game',
#   'judge',
#   'name',
#   'captain',
#   'plate',
#   'thursday',
#   'judge',
#   'judge',
#   'home',
#   'moment',
#   'fact',
#   'home',
#   'run',
#   'york',
#   'offseason',
#   'team',
#   'judge',
#   'judge',
#   'contract',
#   'california',
#   'deal',
#   'remain',
#   'judge',
#   'process',
#   'display',
#   'eye',
#   'guy',
#   'ballpark',
#   'york',
#   'manager',
#   'boone',
#   'home',
#   'run',
#   'day',
#   'center',
#   'chore',
#   'kind',
#   'let',
#   'gerrit',
#   'cole',
#   'captain'],
#  'aaron-rodgers-darkness-retreat-to-start-intl-spt': ['bay',
#   'aaron',
#   'darkness',
#   'retreat',
#   'place',
#   'darkness',
#   'retreat',
#   'week',
#   'realize',
#   'mcafee',
#   'tuesday',
#   'trip',
#   'week',
#   'mcafee',
#   'retreat',
#   'point',
#   'experience',
#   'produce',
#   'drug',
#   'dimethyltryptamine',
#   'dmt',
#   'tuesday',
#   'mvp',
#   'mcafee',
#   'retreat',
#   'entail',
#   'eat',
#   'day',
#   'film',
#   'quarterback',
#   'judgment',
#   'news',
#   'thing',
#   'work',
#   'darkness',
#   'retreat',
#   'meditation',
#   'mind',
#   'headspace',
#   'peace',
#   'life',
#   'retreat',
#   'time',
#   'uncertainty',
#   'contract',
#   'extension',
#   'year',
#   'speculation',
#   'trade',
#   'departure',
#   'team',
#   'university',
#   'california',
#   'berkeley',
#   'top',
#   'year',
#   'time',
#   'tuesday',
#   'retreat',
#   'purpose',
#   'football',
#   'career',
#   'perspective',
#   'bowl',
#   'gon',
#   'retreat',
#   'sense',
#   'life',
#   'retreat',
#   'figure',
#   'play',
#   'year',
#   'week',
#   'isolation',
#   'retreat',
#   'decision',
#   'feel',
#   'interest',
#   'happiness',
#   'football',
#   'career',
#   'surrender',
#   'healing',
#   'medicine',
#   'process'],
#  'aaron-rodgers-decision-darkness-spt-intl': ['darkness',
#   'retreat',
#   'bay',
#   'aaron',
#   'interview',
#   'decision',
#   'anybody',
#   'interest',
#   'decision',
#   'sooner',
#   'interview',
#   'aubrey',
#   'marcus',
#   'remember',
#   'brett',
#   'favre',
#   'come',
#   'offseason',
#   'march',
#   'kind',
#   'june',
#   'tension',
#   'everybody',
#   'decision',
#   'month',
#   'point',
#   'experience',
#   'drug',
#   'dimethyltryptamine',
#   'dmt',
#   'time',
#   'isolation',
#   'peace',
#   'mind',
#   'interview',
#   'retreat',
#   'someone',
#   'tell',
#   'darkness',
#   'finality',
#   'drag',
#   'anybody',
#   'look',
#   'drama',
#   'diva',
#   'whatever',
#   'tune',
#   'decision',
#   'road'],
#  'aaron-rodgers-introduced-new-york-jets-spt-intl': ['nfl',
#   'mvp',
#   'bowl',
#   'champion',
#   'aaron',
#   'york',
#   'surreal',
#   'day',
#   'city',
#   'coach',
#   'robert',
#   'saleh',
#   'direction',
#   'manager',
#   'joe',
#   'douglas',
#   'couple',
#   'bay',
#   'organization',
#   'chapter',
#   'guy',
#   'part',
#   'team',
#   'win',
#   'place',
#   'walking',
#   'facility',
#   'morning',
#   'super',
#   'bowl',
#   'trophy',
#   'bay',
#   'quarterback',
#   'choice',
#   'nfl',
#   'selection',
#   'pick',
#   'draft',
#   'pick',
#   'season',
#   'team',
#   'focus',
#   'season',
#   'duration',
#   'say',
#   'press',
#   'conference',
#   'football',
#   'hall',
#   'famer',
#   'joe',
#   'mention',
#   'namath',
#   'jersey',
#   'quarterback',
#   'broadway',
#   'career',
#   'bay',
#   'victory',
#   'pittsburgh',
#   'bowl',
#   'xlv',
#   'record',
#   'season',
#   'year'],
#  'aaron-rodgers-joe-douglas-new-york-jets-nfl-spt-intl': ['york',
#   'manager',
#   'joe',
#   'douglas',
#   'deal',
#   'nfl',
#   'mvp',
#   'aaron',
#   'bay',
#   'trade',
#   'time',
#   'making',
#   'press',
#   'everything',
#   'thank',
#   'manager',
#   'brian',
#   'gutekunst',
#   'dialogue',
#   'get',
#   'trade',
#   'trade',
#   'pick',
#   'nfl',
#   'draft',
#   'espn',
#   'pick',
#   'draft',
#   'draft',
#   'pick',
#   'season',
#   'schefter',
#   'game',
#   'opportunity',
#   'player',
#   'caliber',
#   'look',
#   'culture',
#   'someone',
#   'character',
#   'nfl',
#   'career',
#   'victory',
#   'super',
#   'bowl',
#   'instagram',
#   'tuesday',
#   'gratitude',
#   'state',
#   'wisconsin',
#   'organization',
#   'season',
#   'opportunity',
#   'time',
#   'opportunity',
#   'deal',
#   'recipient',
#   'ghent',
#   'york',
#   'announce',
#   'team',
#   'select',
#   'round',
#   'osteosarcoma',
#   'bone',
#   'cancer',
#   'tibia',
#   'nfl',
#   'draft',
#   'night',
#   'kansas',
#   'city',
#   'missouri'],
#  'aaron-rodgers-new-york-jets-spt-intl': ['appearance',
#   'pat',
#   'mcafee',
#   'wednesday',
#   'bay',
#   'aaron',
#   'intention',
#   'continue',
#   'york',
#   'think',
#   'friday',
#   'intention',
#   'play',
#   'intention',
#   'york',
#   'league',
#   'mvp',
#   'super',
#   'bowl',
#   'professional',
#   'career',
#   'side',
#   'love',
#   'appreciation',
#   'gratitude',
#   'everything',
#   'bay',
#   'heart',
#   'reality',
#   'situation',
#   'move',
#   'let',
#   'play',
#   'york',
#   'matter',
#   'time',
#   'oregon',
#   'facility',
#   'sure',
#   'packer',
#   'quarterback',
#   'bitterness',
#   'trade',
#   'move',
#   'quarterback',
#   'brett',
#   'favre',
#   'bay',
#   'play',
#   'season',
#   'york',
#   'team'],
#  'aaron-rodgers-nfl-future-darkness-intl-spt': ['hello',
#   'darkness',
#   'aaron',
#   'speculation',
#   'bay',
#   'route',
#   'path',
#   'opportunity',
#   'isolation',
#   'lot',
#   'decision',
#   'mvp',
#   'appearance',
#   'pat',
#   'mcafee',
#   'show',
#   'point',
#   'experience',
#   'produce',
#   'drug',
#   'dimethyltryptamine',
#   'dmt',
#   'darkness',
#   'walk',
#   'darkness',
#   'retreat',
#   'something',
#   'number',
#   'profound',
#   'isolation',
#   'meditation',
#   'kind',
#   'silence',
#   'phone',
#   'psychedelic',
#   'drink',
#   'retreat',
#   'offseason',
#   'drug',
#   'darkness',
#   'retreat',
#   'time',
#   'uncertainty',
#   'bumper',
#   'contract',
#   'extension',
#   'year',
#   'speculation',
#   'trade',
#   'departure',
#   'team',
#   'university',
#   'california',
#   'berkeley',
#   'top',
#   'time',
#   'retirement',
#   'thing',
#   'week',
#   'isolation',
#   'retreat',
#   'decision',
#   'feel',
#   'interest',
#   'happiness',
#   'move'],
#  'aaron-rodgers-out-for-2023-season-injury-spt-intl': ['quarterback',
#   'aaron',
#   'york',
#   'field',
#   'suffering',
#   'injury',
#   'play',
#   'monday',
#   'night',
#   'football',
#   'game',
#   'buffalo',
#   'rest',
#   'nfl',
#   'coach',
#   'robert',
#   'saleh',
#   'call',
#   'tuesday',
#   'saleh',
#   'information',
#   'surgery',
#   'schedule',
#   'recovery',
#   'player',
#   'league',
#   'multiple',
#   'cnn',
#   'mri',
#   'tuesday',
#   'outlook',
#   'injury',
#   'twitter',
#   'way',
#   'commitment',
#   'team',
#   'get',
#   'injury',
#   'staff',
#   'field',
#   'metlife',
#   'stadium',
#   'rutherford',
#   'tent',
#   'locker',
#   'room',
#   'cart',
#   'saleh',
#   'imagine',
#   'coach',
#   'talk',
#   'quarterback',
#   'let',
#   'backup',
#   'zach',
#   'wilson',
#   'quarterback',
#   'void',
#   'team',
#   'overtime',
#   'victory',
#   'rookie',
#   'receiver',
#   'gipson',
#   'punt',
#   'action',
#   'field',
#   'game',
#   'september',
#   'terrorist',
#   'game',
#   'york',
#   'city',
#   'washington',
#   'shanksville',
#   'reaction',
#   'injury',
#   'emotion',
#   'loss',
#   'player',
#   'piece',
#   'espn',
#   'host',
#   'greenberg',
#   'roller',
#   'coaster',
#   'anyone',
#   'today',
#   'reality',
#   'anybody',
#   'mad',
#   'greenberg',
#   'game',
#   'place',
#   'time',
#   'hope',
#   'team',
#   'fan',
#   'season',
#   'minimum',
#   'half',
#   'league',
#   'injury',
#   'everything',
#   'team',
#   'season',
#   'organization',
#   'aaron',
#   'moment',
#   'idea',
#   'season',
#   'team',
#   'analyst',
#   'player',
#   'see',
#   'aaron',
#   'game',
#   'wire',
#   'league',
#   'mvp',
#   'moment',
#   'glory',
#   'joe',
#   'namath',
#   'bowl',
#   'bowl',
#   'contender',
#   'night',
#   'wire',
#   'york',
#   'team',
#   'lot',
#   'offseason',
#   'career',
#   'bay',
#   'victory',
#   'super',
#   'bowl',
#   'accuracy',
#   'deadliness',
#   'speculation',
#   'role',
#   'field',
#   'metlife',
#   'stadium',
#   'injury',
#   'something',
#   'discuss',
#   'kind',
#   'think',
#   'saleh',
#   'news',
#   'grass',
#   'lot',
#   'bay',
#   'lineman',
#   'teammate',
#   'david',
#   'bakhtiari',
#   'turf',
#   'league',
#   'turf',
#   'care',
#   'soccer',
#   'plan',
#   'turf',
#   'world',
#   'cup',
#   'post',
#   'site',
#   'sick',
#   'difference',
#   'rate',
#   'grass',
#   'jeff',
#   'miller',
#   'executive',
#   'vice',
#   'president',
#   'policy',
#   'health',
#   'safety',
#   'news',
#   'conference',
#   'injury',
#   'surface',
#   'case',
#   'difference',
#   'miller',
#   'lot',
#   'work',
#   'prevent',
#   'message',
#   'change',
#   'grass',
#   'soccer',
#   'field',
#   'football',
#   'miller',
#   'spend',
#   'lot',
#   'time',
#   'injury',
#   'game',
#   'use',
#   'miller',
#   'grass',
#   'injury',
#   'rate',
#   'injury',
#   'rate',
#   'league',
#   'study',
#   'role'],
#  'aaron-rodgers-packers-jets-nfl-spt-intl': ['bay',
#   'trade',
#   'longtime',
#   'aaron',
#   'apple',
#   'manager',
#   'brian',
#   'gutekunst',
#   'gutekunst',
#   'trade',
#   'trade',
#   'trade',
#   'nfl',
#   'player',
#   'pick',
#   'nfl',
#   'draft',
#   'espn',
#   'pick',
#   'draft',
#   'draft',
#   'pick',
#   'season',
#   'nfl',
#   'career',
#   'victory',
#   'super',
#   'bowl',
#   'nfl',
#   'draft',
#   'night',
#   'kansas',
#   'city',
#   'appearance',
#   'pat',
#   'mcafee',
#   'march',
#   'intention',
#   'continue',
#   'side',
#   'love',
#   'appreciation',
#   'gratitude',
#   'everything',
#   'bay',
#   'heart',
#   'quarterback',
#   'reality',
#   'situation',
#   'move',
#   'let',
#   'let',
#   'play',
#   'york',
#   'matter',
#   'cnn',
#   'accuracy',
#   'deadliness',
#   'championship',
#   'playoff',
#   'dissatisfaction',
#   'bay',
#   'work',
#   'heir',
#   'jordan',
#   'love',
#   'round',
#   'retirement',
#   'option',
#   'occasion',
#   'retreat',
#   'offseason',
#   'clarity',
#   'ability',
#   'age',
#   'precision',
#   'canniness',
#   'snap',
#   'knack',
#   'maneuvering',
#   'season',
#   'team',
#   'record',
#   'help',
#   'week',
#   'game',
#   'bay',
#   'end',
#   'season'],
#  'aaron-rodgers-pebble-beach-pro-am-spt-intl': ['chance',
#   'bay',
#   'bowl',
#   'sunday',
#   'aaron',
#   'season',
#   'golf',
#   'partner',
#   'ben',
#   'silverman',
#   'quarterback',
#   'pga',
#   'beach',
#   'sunday',
#   'duo',
#   'victory',
#   'golfer',
#   'peter',
#   'fedex',
#   'president',
#   'ceo',
#   'golf',
#   'monday',
#   'training',
#   'camp',
#   'name',
#   'wall',
#   'list',
#   'deal',
#   'sugarcoat',
#   'week',
#   'spending',
#   'time',
#   'ben',
#   'pair',
#   'california',
#   'event',
#   'event',
#   'tournament',
#   'justin',
#   'resume',
#   'gridiron',
#   'time',
#   'year',
#   'june',
#   'veteran',
#   'tom',
#   'brady',
#   'quarterback',
#   'edition',
#   'match',
#   'duo',
#   'josh',
#   'buffalo',
#   'keith',
#   'mitchell',
#   'rivalry',
#   'think',
#   'name',
#   'wall',
#   'speculation',
#   'trade',
#   'season',
#   'talk',
#   'departure',
#   'nfl',
#   'team',
#   'tweet',
#   'teammate',
#   'davante',
#   'twitter',
#   'neighborhood',
#   'beach',
#   'footage',
#   'wry',
#   'bowl',
#   'winner',
#   'return',
#   'humor',
#   'change',
#   'reception',
#   'year',
#   'francisco',
#   'lot',
#   'trash',
#   'year',
#   'couple',
#   'york',
#   'lot',
#   'presence',
#   'hear',
#   'ben',
#   'meanwhile',
#   'footballer',
#   'gareth',
#   'bale',
#   'partner',
#   'joseph',
#   'madrid',
#   'tottenham',
#   'round',
#   'cart',
#   'couple',
#   'amazing',
#   'bale',
#   'game',
#   'pressure',
#   'golf',
#   'fan',
#   'appreciate',
#   'play',
#   'watch',
#   'event',
#   'trio',
#   'malnati',
#   'brendon',
#   'champion',
#   'tour',
#   'winner',
#   'victory',
#   'insurance'],
#  'aaron-rodgers-profile-explainer-jets-packers-spt-intl': ['quarterback',
#   'team',
#   'aim',
#   'bowl',
#   'fan',
#   'bay',
#   'york',
#   'history',
#   'hall',
#   'fame',
#   'quarterback',
#   'brett',
#   'favre',
#   'business',
#   'aaron',
#   'jersey',
#   'process',
#   'trade',
#   'become',
#   'gang',
#   'quarterback',
#   'jigsaw',
#   'piece',
#   'bowl',
#   'nfl',
#   'draft',
#   'part',
#   'room',
#   'amongst',
#   'college',
#   'california',
#   'kid',
#   'pick',
#   'sore',
#   'need',
#   'quarterback',
#   'smith',
#   'wait',
#   'podium',
#   'none',
#   'pick',
#   'slip',
#   'name',
#   'nfl',
#   'sword',
#   'california',
#   'favre',
#   'position',
#   'bowl',
#   'title',
#   'season',
#   'mvp',
#   'countless',
#   'accuracy',
#   'deadliness',
#   'championship',
#   'playoff',
#   'dissatisfaction',
#   'bay',
#   'work',
#   'love',
#   'round',
#   'retirement',
#   'occasion',
#   'retreat',
#   'offseason',
#   'clarity',
#   'wednesday',
#   'agency',
#   'opening',
#   'world',
#   'sure',
#   'packer',
#   'reality',
#   'situation',
#   'move',
#   'let',
#   'appearance',
#   'pat',
#   'mcafee',
#   'play',
#   'york',
#   'matter',
#   'december',
#   'tom',
#   'age',
#   'number',
#   'season',
#   'drop',
#   'year',
#   'start',
#   'season',
#   'team',
#   'record',
#   'help',
#   'week',
#   'game',
#   'spot',
#   'team',
#   'end',
#   'ability',
#   'precision',
#   'canniness',
#   'snap',
#   'knack',
#   'maneuvering',
#   'quarterback',
#   'pick',
#   'zach',
#   'wilson',
#   'darnold',
#   'world',
#   'manager',
#   'joe',
#   'coach',
#   'robert',
#   'saleh',
#   'roster',
#   'position',
#   'excellent',
#   'draft',
#   'cornerback',
#   'sauce',
#   'gardner',
#   'receiver',
#   'garrett',
#   'wilson',
#   'rookie',
#   'year',
#   'hall',
#   'case',
#   'consideration',
#   'injury',
#   'collection',
#   'mosley',
#   'line',
#   'defense',
#   'piece',
#   'championship',
#   'end',
#   'brady',
#   'england',
#   'tampa',
#   'bay',
#   'age',
#   'bowl',
#   'title',
#   'season',
#   'lack',
#   'success',
#   'time',
#   'wilderness',
#   'struggle',
#   'environment',
#   'thing',
#   'sure',
#   'green'],
#  'abortion-decriminalization-reproductive-justice-protests-intl-gbr': ['street',
#   'court',
#   'picket',
#   'decide',
#   'demanding',
#   'abortion',
#   'month',
#   'woman',
#   'medication',
#   'terminate',
#   'pregnancy',
#   'limit',
#   'legislation',
#   'case',
#   'justice',
#   'woman',
#   'custody',
#   'license',
#   'year',
#   'court',
#   'wade',
#   'protest',
#   'movement',
#   'abortion',
#   'access',
#   'progress',
#   'increase',
#   'access',
#   'health',
#   'state',
#   'government',
#   'abortion',
#   'nadia',
#   'hirsi',
#   'actress',
#   'theater',
#   'maker',
#   'london',
#   'cnn',
#   'jennifer',
#   'dean',
#   'blogger',
#   'protest',
#   'body',
#   'choice',
#   'community',
#   'womb',
#   'choice',
#   'jenny',
#   'wickham',
#   'campaigner',
#   'cnn',
#   'liberalization',
#   'abortion',
#   'law',
#   'threat',
#   'abortion',
#   'pregnancy',
#   'prison',
#   'sentence',
#   'life',
#   'case',
#   'sentence',
#   'judge',
#   'court',
#   'england',
#   'person',
#   'act',
#   'woman',
#   'time',
#   'medication',
#   'court',
#   'barrister',
#   'charlotte',
#   'proudman',
#   'act',
#   'interview',
#   'cnn',
#   'time',
#   'proudman',
#   'letter',
#   'director',
#   'summer',
#   'time',
#   'prosecution',
#   'change',
#   'letter',
#   'fear',
#   'landmark',
#   'conviction',
#   'decade',
#   'place',
#   'england',
#   'legislation',
#   'opposition',
#   'lawmaker',
#   'stella',
#   'creasy',
#   'parliament',
#   'june',
#   'proudman',
#   'outrage',
#   'conviction',
#   'fact',
#   'woman',
#   'type',
#   'think',
#   'proudman',
#   'decision',
#   'court',
#   'year',
#   'landmark',
#   'roe',
#   'wade',
#   'ruling',
#   'state',
#   'abortion',
#   'thinking',
#   'minute',
#   'look',
#   'england',
#   'fact',
#   'abortion',
#   'offense',
#   'subject',
#   'parliament',
#   'legislation',
#   'criminalization',
#   'abortion',
#   'ireland',
#   'rest',
#   'charity',
#   'katherine',
#   'pregnancy',
#   'service',
#   'bpas',
#   'argument',
#   'extension',
#   'legislation',
#   'rest',
#   'law',
#   'allow',
#   'access',
#   'abortion',
#   'care',
#   'ireland',
#   'criminalization',
#   'proudman',
#   'barrister',
#   'example',
#   'decision',
#   'abortion',
#   'conviction',
#   'abortion',
#   'talk',
#   'poland',
#   'talk',
#   'life',
#   'pregnancy',
#   'abortion',
#   'care',
#   'health',
#   'crisis',
#   'annabel',
#   'sowemimo',
#   'community',
#   'health',
#   'registrar',
#   'abortion',
#   'access',
#   'procedure',
#   'pregnancy',
#   'comfort',
#   'august',
#   'government',
#   'access',
#   'legislation',
#   'access',
#   'home',
#   'gestation',
#   'england',
#   'uptake',
#   'abortion',
#   'act',
#   'government',
#   'abortion',
#   'point',
#   'delivery',
#   'access',
#   'abortion',
#   'issue',
#   'inquiry',
#   'control',
#   'prevention',
#   'cause',
#   'racism',
#   'abortion',
#   'care',
#   'health',
#   'service',
#   'abortion',
#   'life',
#   'abortion',
#   'crime',
#   'care',
#   'impact',
#   'voting',
#   'record',
#   'encouragement',
#   'abortion',
#   'buffer',
#   'extension',
#   'provision',
#   'abortion',
#   'action',
#   'decriminalization',
#   'agenda',
#   'consensus',
#   'work',
#   'work',
#   'support',
#   'compassion'],
#  'ac-milan-inter-champions-league-semifinal-preview-spt-intl': ['place',
#   'stake',
#   'inter',
#   'start',
#   'tie',
#   'simone',
#   'team',
#   'victory',
#   'time',
#   'match',
#   'minute',
#   'džeko',
#   'inter',
#   'mkhitaryan',
#   'bursting',
#   'box',
#   'mike',
#   'inter',
#   'cup',
#   'suggestion',
#   'atmosphere',
#   'end',
#   'difference',
#   'clock',
#   'džeko',
#   'corner',
#   'wealth',
#   'home',
#   'corner',
#   'milan',
#   'davide',
#   'side',
#   'mkhitaryan',
#   'kept',
#   'cool',
#   'strike',
#   'ball',
#   'maignan',
#   'milan',
#   'stefano',
#   'side',
#   'inter',
#   'hakan',
#   'shot',
#   'post',
#   'inter',
#   'penalty',
#   'captain',
#   'martínez',
#   'box',
#   'jesus',
#   'gil',
#   'manzano',
#   'decision',
#   'help',
#   'džeko',
#   'opportunity',
#   'milan',
#   'home',
#   'side',
#   'perform',
#   'half',
#   'side',
#   'inter',
#   'goal',
#   'shot',
#   'paper',
#   'result',
#   'džeko',
#   'result',
#   'nothing',
#   'milan',
#   'fikayo',
#   'tomori',
#   'start',
#   'half',
#   'bit',
#   'anxiety',
#   'game',
#   'millimeter',
#   'dwell',
#   'game',
#   'leg',
#   'milan',
#   'place',
#   'place',
#   'manchester',
#   'city',
#   'victor',
#   'june'],
#  'achraf-hakimi-rape-investigation-spt-intl': ['investigation',
#   'rape',
#   'soccer',
#   'player',
#   'achraf',
#   'hakimi',
#   'source',
#   'investigation',
#   'office',
#   'paris',
#   'investigation',
#   'source',
#   'hakimi',
#   'penalty',
#   'kick',
#   'morocco',
#   'world',
#   'cup',
#   'office',
#   'comment',
#   'investigation',
#   'information',
#   'truth',
#   'office',
#   'cnn',
#   'statement',
#   'cnn',
#   'wednesday',
#   'psg',
#   'spokesperson',
#   'club',
#   'player',
#   'institution',
#   'hakimi',
#   'world',
#   'inter',
#   'milan',
#   'messi',
#   'year',
#   'ceremony',
#   'paris',
#   'monday'],
#  'activists-vandalize-yacht-ibiza-climate-intl': ['superyacht',
#   'group',
#   'superyacht',
#   'kaos',
#   'banner',
#   'vessel',
#   'world',
#   'population',
#   'pain',
#   'misery',
#   'planet',
#   'habitability',
#   'land',
#   'everything',
#   'standard',
#   'living',
#   'reason',
#   'shipping',
#   'industry',
#   'news',
#   'walton',
#   'laurie',
#   'billionaire',
#   'heiress',
#   'cnn',
#   'comment',
#   'guard',
#   'sunday',
#   'morning',
#   'monday',
#   'act',
#   'friday',
#   'group',
#   'spray',
#   'jet',
#   'ibiza',
#   'airport',
#   'action',
#   'party',
#   'campaign',
#   'extinction',
#   'rebellion',
#   'demand',
#   'prohibition',
#   'luxury',
#   'climate',
#   'group',
#   'extinction',
#   'rebellion',
#   'make',
#   'leisure',
#   'luxury',
#   'month',
#   'golf',
#   'country',
#   'protest',
#   'water',
#   'use',
#   'golf',
#   'record'],
#  'adam-peaty-swimming-mental-health-spt-scli-intl-gbr': ['champion',
#   'adam',
#   'peaty',
#   'withdrawn',
#   'swimming',
#   'health',
#   'honest',
#   'instagram',
#   'post',
#   'sport',
#   'burnout',
#   'help',
#   'imbalance',
#   'brit',
#   'train',
#   'purpose',
#   'performance',
#   'paris',
#   'olympic',
#   'peaty',
#   'breaststroke',
#   'decade',
#   'world',
#   'record',
#   'world',
#   'record',
#   'year',
#   'breaststroke',
#   'dominance',
#   'gold',
#   'rio',
#   'defend',
#   'olympic',
#   'title',
#   'breaststroke',
#   'event',
#   'foot',
#   'commonwealth',
#   'race',
#   'time',
#   'seat',
#   'sit',
#   'success',
#   'understand',
#   'put',
#   'win',
#   'peaty',
#   'swimming',
#   'statement',
#   'peaty',
#   'assist',
#   'competition',
#   'schedule',
#   'peaty',
#   'family',
#   'swimming',
#   'incredible',
#   'family',
#   'sport',
#   'everything',
#   'love'],
#  'adele-roberts-london-marathon-ileostomy-record-spt-intl': ['radio',
#   'presenter',
#   'woman',
#   'london',
#   'marathon',
#   'ileostomy',
#   'distance',
#   'half',
#   'world',
#   'line',
#   'twitter',
#   'marathon',
#   'ileostomy',
#   'adele',
#   'bbc',
#   'radio',
#   'bowel',
#   'cancer',
#   'stoma',
#   'bag',
#   'surgery',
#   'chemotherapy',
#   'time',
#   'person',
#   'today',
#   'cancer',
#   'procedure',
#   'create',
#   'end',
#   'bowel',
#   'opening',
#   'bag',
#   'ileostomy',
#   'stool',
#   'colon',
#   'hydration',
#   'food',
#   'activity',
#   'race',
#   'london',
#   'marathon',
#   'sunday',
#   'dutch',
#   'runner',
#   'sifan',
#   'kelvin',
#   'kiptum'],
#  'adolf-hitler-birth-house-conversion-intl-scli': ['house',
#   'hitler',
#   'training',
#   'center',
#   'police',
#   'ministry',
#   'building',
#   'town',
#   'braunau',
#   'inn',
#   'accommodate',
#   'facility',
#   'police',
#   'station',
#   'government',
#   'decision',
#   'commission',
#   'property',
#   'appeal',
#   'extremist',
#   'ministry',
#   'face',
#   'place',
#   'perspective',
#   'oliver',
#   'rathkolb',
#   'history',
#   'university',
#   'vienna',
#   'press',
#   'briefing',
#   'hitler',
#   'apartment',
#   'family',
#   'building',
#   'pommer',
#   'family',
#   'building',
#   'birth',
#   'ministry',
#   'site',
#   'sublet',
#   'house',
#   'empty',
#   'tenant',
#   'disability',
#   'center',
#   'government',
#   'property',
#   'set',
#   'pommer',
#   'ministry',
#   'expropriate',
#   'wrangling',
#   'seizure',
#   'compensation',
#   'time',
#   'site',
#   'government',
#   'decision',
#   'transform',
#   'police',
#   'station',
#   'minister',
#   'peschorn',
#   'future',
#   'use',
#   'house',
#   'police',
#   'signal',
#   'building',
#   'office',
#   'human',
#   'organization',
#   'topic',
#   'commission',
#   'member',
#   'hermann',
#   'feiner',
#   'head',
#   'construction',
#   'estate',
#   'ministry',
#   'interior',
#   'statement',
#   'conversion',
#   'cost',
#   'year'],
#  'adolis-garcia-three-home-runs-rangers-athletics-spt-intl': ['perfect',
#   'garcía',
#   'saturday',
#   'home',
#   'homer',
#   'home',
#   'night',
#   'series',
#   'friday',
#   'performance',
#   'garcía',
#   'game',
#   'ranger',
#   'nelson',
#   'cruz',
#   'decade',
#   'night',
#   'garcía',
#   'interpreter',
#   'raul',
#   'cardenas',
#   'something',
#   'happen',
#   'overthinking',
#   'night',
#   'home',
#   'run',
#   'crowd',
#   'tie',
#   'score',
#   'second',
#   'bottom',
#   'garcía',
#   'league',
#   'record',
#   'home',
#   'game',
#   'hit',
#   'wall',
#   'double',
#   'history',
#   'player',
#   'league',
#   'history',
#   'game',
#   'home',
#   'mlb',
#   'league',
#   'home',
#   'run',
#   'garcia',
#   'dominance',
#   'base',
#   'jung',
#   'manage',
#   'manager',
#   'bochy',
#   'player',
#   'way',
#   'joy',
#   'home',
#   'world',
#   'baseball',
#   'play',
#   'game',
#   'way',
#   'play',
#   'love'],
#  'adriana-lima-fifa-moya-dodd-women-world-cup-intl-spt': ['decision',
#   'appoint',
#   'supermodel',
#   'adriana',
#   'lima',
#   'fan',
#   'ambassador',
#   'world',
#   'cup',
#   'moya',
#   'world',
#   'body',
#   'lima',
#   'model',
#   'world',
#   'fifa',
#   'president',
#   'gianni',
#   'infantino',
#   'dodd',
#   'football',
#   'team',
#   'image',
#   'organisation',
#   'president',
#   'gender',
#   'equality',
#   'fifa',
#   'governance',
#   'dodd',
#   'taskforce',
#   'football',
#   'linkedin',
#   'hen',
#   'girl',
#   'football',
#   'world',
#   'footing',
#   'way',
#   'trajectory',
#   'member',
#   'executive',
#   'committee',
#   'dodd',
#   'research',
#   'lima',
#   'model',
#   'eating',
#   'drinking',
#   'article',
#   'abortion',
#   'population',
#   'womensfootball',
#   'game',
#   'equality',
#   'look',
#   'publicist',
#   'boye',
#   'stance',
#   'position',
#   'boye',
#   'statement',
#   'news',
#   'agency',
#   'post',
#   'dodd',
#   'abortion',
#   'criticism',
#   'choice',
#   'everyone',
#   'abortion',
#   'crime',
#   'choice',
#   'prospect',
#   'empowerment',
#   'control',
#   'imho',
#   'cnn',
#   'statement',
#   'monday',
#   'lima',
#   'chosen',
#   'fifa',
#   'fan',
#   'ambassador',
#   'help',
#   'ouarda',
#   'coussay',
#   'model',
#   'management',
#   'agency',
#   'world',
#   'group',
#   'lima',
#   'comment',
#   'world',
#   'cup',
#   'zealand'],
#  'afc-playoffs-neutral-site-proposal-nfl-spt': ['nfl',
#   'postseason',
#   'plan',
#   'cancellation',
#   'buffalo',
#   'game',
#   'game',
#   'football',
#   'conference',
#   'league',
#   'meeting',
#   'team',
#   'determine',
#   'playoff',
#   'season',
#   'monday',
#   'game',
#   'damar',
#   'hamlin',
#   'field',
#   'buffalo',
#   'solution',
#   'commissioner',
#   'roger',
#   'goodell',
#   'proposal',
#   'competition',
#   'committee',
#   'approval',
#   'proposal',
#   'ownership',
#   'consider',
#   'decision',
#   'play',
#   'game',
#   'nfl',
#   'plan',
#   'championship',
#   'game',
#   'site',
#   'number',
#   'seed',
#   'game',
#   'city',
#   'weekend',
#   'potential',
#   'seed',
#   'playoff',
#   'seed',
#   'season',
#   'saturday',
#   'playoff',
#   'picture',
#   'season',
#   'percentage',
#   'nfl',
#   'game',
#   'loss',
#   'tie',
#   'release',
#   'scenario',
#   'buffalo',
#   'city',
#   'win',
#   'tie',
#   'buffalo',
#   'city',
#   'championship',
#   'game',
#   'scenario',
#   'buffalo',
#   'city',
#   'baltimore',
#   'buffalo',
#   'city',
#   'championship',
#   'game',
#   'scenario',
#   'buffalo',
#   'city',
#   'cincinnati',
#   'buffalo',
#   'cincinnati',
#   'city',
#   'championship',
#   'game',
#   'plan',
#   'coin',
#   'flip',
#   'determine',
#   'home',
#   'field',
#   'end',
#   'card',
#   'schedule',
#   'imbalance',
#   'chance',
#   'win',
#   'baltimore',
#   'week',
#   'cincinnati',
#   'opponent',
#   'host',
#   'playoff',
#   'game',
#   'cincinnati',
#   'percentage',
#   'schedule',
#   'schedule',
#   'nfl',
#   'news',
#   'baltimore',
#   'victory',
#   'record',
#   'division',
#   'vote',
#   'pass'],
#  'afd-victory-germany-district-elections-intl': ['germany',
#   'afd',
#   'party',
#   'leadership',
#   'post',
#   'time',
#   'victory',
#   'group',
#   'agenda',
#   'surveillance',
#   'robert',
#   'sesselmann',
#   'jürgen',
#   'union',
#   'cdu',
#   'party',
#   'district',
#   'administrator',
#   'sonneberg',
#   'thuringia',
#   'germany',
#   'vote',
#   'köpper',
#   'state',
#   'office',
#   'opposition',
#   'win',
#   'center',
#   'rise',
#   'populism',
#   'election',
#   'state',
#   'party',
#   'election',
#   'chancellor',
#   'olaf',
#   'chairwoman',
#   'saskia',
#   'esken',
#   'victory',
#   'chairwoman',
#   'party',
#   'ricarda',
#   'lang',
#   'result',
#   'state',
#   'election',
#   'sonneberg',
#   'dismaying',
#   'mario',
#   'czaja',
#   'secretary',
#   'cdu',
#   'result',
#   'government',
#   'spokesman',
#   'hebestreit',
#   'democracy',
#   'invasion',
#   'ukraine',
#   'inflation',
#   'energy',
#   'climate',
#   'transformation',
#   'migrant',
#   'crisis',
#   'group',
#   'something',
#   'country',
#   'future',
#   'hebestreit',
#   'status',
#   'party',
#   'world',
#   'war',
#   'march',
#   'surveillance',
#   'bfv',
#   'intelligence',
#   'service',
#   'suspicion',
#   'constitution',
#   'party',
#   'way',
#   'era',
#   'year',
#   'bfv',
#   'youth',
#   'wing',
#   'move',
#   'party',
#   'afd',
#   'segment',
#   'migration',
#   'scientist',
#   'berlin',
#   'change',
#   'opinion',
#   'state',
#   'afd',
#   'vorländer',
#   'cnn',
#   'monday',
#   'election',
#   'participation',
#   'form',
#   'government',
#   'mood',
#   'government',
#   'population',
#   'saxony',
#   'thuringia',
#   'germany',
#   'victory',
#   'victory',
#   'afd',
#   'state',
#   'afd',
#   'number',
#   'level',
#   'alice',
#   'weidel',
#   'history',
#   'administrator',
#   'victory'],
#  'afd-youth-wing-extremist-label-intl': ['intelligence',
#   'monitor',
#   'germany',
#   'party',
#   'afd',
#   'time',
#   'party',
#   'aim',
#   'youth',
#   'faction',
#   'cnn',
#   'look',
#   'intelligence',
#   'agency',
#   'office',
#   'protection',
#   'constitution',
#   'bfv',
#   'group',
#   'statement',
#   'april',
#   'intelligence',
#   'agency',
#   'youth',
#   'wing',
#   'junge',
#   'für',
#   'deutschland',
#   'concept',
#   'society',
#   'group',
#   'move',
#   'parent',
#   'party',
#   'afd',
#   'state',
#   'monitor',
#   'mail',
#   'correspondence',
#   'phone',
#   'ability',
#   'employment',
#   'public',
#   'sector',
#   'party',
#   'extremist',
#   'life',
#   'line',
#   'germany',
#   'afghanistan',
#   'gnauck',
#   'member',
#   'parliament',
#   'chairman',
#   'democracy',
#   'year',
#   'parent',
#   'party',
#   'party',
#   'facebook',
#   'page',
#   'example',
#   'feminism',
#   'post',
#   'chairman',
#   'philipp',
#   'ritz',
#   'organization',
#   'bfv',
#   'worldview',
#   'anyone',
#   'president',
#   'thomas',
#   'haldenwang',
#   'evidence',
#   'attitude',
#   'october',
#   'army',
#   'speaking',
#   'designation',
#   'gnauck',
#   'ounce',
#   'afd',
#   'shot',
#   'prominence',
#   'decision',
#   'praise',
#   'criticism',
#   'allow',
#   'war',
#   'stance',
#   'issue',
#   'gnauck',
#   'village',
#   'perception',
#   'evidence',
#   'link',
#   'immigration',
#   'past',
#   'gnauck',
#   'appeal',
#   'cool',
#   'person',
#   'man',
#   'woman',
#   'job',
#   'life',
#   'home',
#   'gnauck',
#   'designation',
#   'extremist',
#   'expecting',
#   'state',
#   'chairman',
#   'saxony',
#   'alexander',
#   'wiesner',
#   'intelligence',
#   'agency',
#   'stasi',
#   'germany',
#   'tradition',
#   'saxony',
#   'zone',
#   'gdr',
#   'mind',
#   'thing',
#   'cnn',
#   'agency',
#   'protection',
#   'kiess',
#   'extremism',
#   'leipzig',
#   'germany',
#   'youth',
#   'view',
#   'organization',
#   'extreme',
#   'sister',
#   'party',
#   'minister',
#   'nancy',
#   'faeser',
#   'danger',
#   'ideology',
#   'advert',
#   'party',
#   'post',
#   'hierarchy',
#   'party',
#   'overthrow',
#   'state',
#   'rebuild',
#   'course',
#   'country',
#   'change',
#   'move',
#   'crackdown',
#   'state',
#   'policy',
#   'percent',
#   'association',
#   'time',
#   'germany',
#   'year',
#   'attempt',
#   'group',
#   'reichsbuerger',
#   'movement',
#   'plot',
#   'attack',
#   'parliament',
#   'building',
#   'order',
#   'install',
#   'figure',
#   'aristocrat',
#   'heinrich',
#   'prince',
#   'reuss',
#   'prince',
#   'gnauck',
#   'party',
#   'afd',
#   'popularity',
#   'party',
#   'election',
#   'vote',
#   'status',
#   'party',
#   'world',
#   'war',
#   'party',
#   'energy',
#   'invasion',
#   'kiess',
#   'migration',
#   'germany',
#   'reason',
#   'migration',
#   'debate',
#   'government',
#   'conflict',
#   'state',
#   'kind',
#   'debate',
#   'migration',
#   'war',
#   'conflict',
#   'germany',
#   'addition',
#   'government',
#   'migration',
#   'become',
#   'challenge',
#   'poll',
#   'country',
#   'kiess',
#   'fact',
#   'afd',
#   'migration',
#   'discourse',
#   'afd',
#   'thing',
#   'migration',
#   'attention',
#   'organization',
#   'popularity',
#   'gnauck',
#   'classification',
#   'license',
#   'sector',
#   'example',
#   'police'],
#  'afghanistan-british-forces-investigation-intl': ['probe',
#   'part',
#   'effort',
#   'war',
#   'coverups',
#   'saifullahs',
#   'noorzais',
#   'justice',
#   'inquiry',
#   'defense',
#   'secretary',
#   'ben',
#   'wallace',
#   'member',
#   'family',
#   'time',
#   'handcuffed',
#   'family',
#   'home',
#   'head',
#   'tea',
#   'family',
#   'probe',
#   'cover',
#   'judge',
#   'investigation',
#   'anyone',
#   'information',
#   'question',
#   'mechanism',
#   'team',
#   'group',
#   'work',
#   'security',
#   'material',
#   'team',
#   'time',
#   'war',
#   'court',
#   'investigation',
#   'conduct',
#   'iraq',
#   'examination',
#   'investigation',
#   'part',
#   'response',
#   'army',
#   'inquiry',
#   'police',
#   'investigation',
#   'part',
#   'work',
#   'determine',
#   'coverup',
#   'level',
#   'work',
#   'power',
#   'compel',
#   'order',
#   'reproduction',
#   'cooperation',
#   'reputation',
#   'country'],
#  'afl-jamarra-ugle-hagan-anti-racism-gesture-spt-intl': ['football',
#   'league',
#   'afl',
#   'star',
#   'goal',
#   'stand',
#   'racism',
#   'game',
#   'fan',
#   'racist',
#   'march',
#   'shirt',
#   'kicking',
#   'goal',
#   'brisbane',
#   'player',
#   'gesture',
#   'landmark',
#   'moment',
#   'fight',
#   'image',
#   'debate',
#   'league',
#   'education',
#   'campaign',
#   'game',
#   'racist',
#   'abuse',
#   'museum',
#   'fan',
#   'remark',
#   'game',
#   'incident',
#   'integrity',
#   'department',
#   'identify',
#   'thursday',
#   'career',
#   'brisbane',
#   'make',
#   'stance',
#   'show',
#   'presence',
#   'interview',
#   'weekend',
#   'point',
#   'boy',
#   'play',
#   'football',
#   'winmar',
#   'jersey',
#   'racist',
#   'abuse',
#   'team',
#   'match',
#   'april',
#   'statement',
#   'friday',
#   'winmar',
#   'time',
#   'stance',
#   'issue',
#   'relay',
#   'race',
#   'time',
#   'pass',
#   'baton',
#   'winmar',
#   'awareness',
#   'racism',
#   'sport',
#   'society',
#   'supporting',
#   'statement',
#   'vilification',
#   'anyone',
#   'community'],
#  'afp-journalist-arman-soldin-killed-ukraine-intl-hnk': ['journalist',
#   'news',
#   'agency',
#   'agence',
#   'afp',
#   'rocket',
#   'fire',
#   'city',
#   'bakhmut',
#   'arman',
#   'soldin',
#   'video',
#   'coordinator',
#   'ukraine',
#   'rocket',
#   'attack',
#   'town',
#   'chasiv',
#   'yar',
#   'bakhmut',
#   'afp',
#   'twitter',
#   'death',
#   'afp',
#   'video',
#   'journalist',
#   'arman',
#   'today',
#   'family',
#   'time',
#   'attack',
#   'news',
#   'agency',
#   'reporting',
#   'team',
#   'fire',
#   'time',
#   'tuesday',
#   'soldin',
#   'citizen',
#   'reporter',
#   'news',
#   'agency',
#   'video',
#   'coordinator',
#   'september',
#   'conflict',
#   'area',
#   'report',
#   'region',
#   'epicenter',
#   'afp',
#   'soldin',
#   'start',
#   'invasion',
#   'news',
#   'photojournalist',
#   'pierre',
#   'consultant',
#   'oleksandra',
#   'journalist',
#   'brent',
#   'renaud',
#   'photojournalist',
#   'sarajevo',
#   'france',
#   'war',
#   'interview',
#   'year',
#   'rome',
#   'staff',
#   'london',
#   'year',
#   'news',
#   'news',
#   'death',
#   'grief',
#   'agency',
#   'loss',
#   'arman',
#   'ceo',
#   'afp',
#   'news',
#   'death',
#   'reminder',
#   'basis',
#   'conflict',
#   'month',
#   'soldin',
#   'camera',
#   'team',
#   'rocket',
#   'fire',
#   'caught',
#   'rain',
#   'grad',
#   'yesterday',
#   'ukraine',
#   'enthusiasm',
#   'video',
#   'tribute',
#   'pop',
#   'song',
#   'twitter',
#   'series',
#   'baby',
#   'hedgehog',
#   'team',
#   'crater',
#   'chasiv',
#   'soldin',
#   'hedgehog',
#   'base',
#   'kind',
#   'guy',
#   'war',
#   'personality',
#   'miss',
#   'rest',
#   'peace',
#   'brown',
#   'news',
#   'editor',
#   'moscow',
#   'kyiv',
#   'president',
#   'macron',
#   'death',
#   'twitter',
#   'share',
#   'family',
#   'courage',
#   'inform',
#   'share',
#   'pain',
#   'ambassador',
#   'sergiy',
#   'kyslytsya',
#   'soldin',
#   'life',
#   'respect',
#   'war',
#   'ukraine',
#   'march',
#   'kramatorsk',
#   'bottle',
#   'occasion',
#   'colleague',
#   'guitar',
#   'antoine',
#   'lambroschini'],
#  'african-leaders-putin-peace-meeting-intl-ukr': ['peace',
#   'vladimir',
#   'putin',
#   'petersburg',
#   'leader',
#   'lack',
#   'africa',
#   'delegation',
#   'russia',
#   'goal',
#   'delegation',
#   'president',
#   'cyril',
#   'ramaphosa',
#   'war',
#   'putin',
#   'kremlin',
#   'line',
#   'moscow',
#   'dialogue',
#   'kyiv',
#   'salute',
#   'dialogue',
#   'peace',
#   'consideration',
#   'legitimate',
#   'putin',
#   'russia',
#   'recognition',
#   'territory',
#   'something',
#   'question',
#   'war',
#   'year',
#   'result',
#   'grain',
#   'putin',
#   'turmoil',
#   'food',
#   'market',
#   'fault',
#   'war',
#   'president',
#   'conflict',
#   'putin',
#   'arrest',
#   'warrant',
#   'court',
#   'icc',
#   'deport',
#   'ramaphosa',
#   'conflict',
#   'putin',
#   'delegation',
#   'zambia',
#   'comoros',
#   'congo',
#   'brazzaville',
#   'egypt',
#   'senegal',
#   'meet',
#   'president',
#   'volodymyr',
#   'shelter',
#   'delegation',
#   'continent',
#   'conflict',
#   'ramaphosa',
#   'zelensky',
#   'peace',
#   'kyiv',
#   'table',
#   'peace',
#   'land',
#   'war',
#   'freeze',
#   'pain',
#   'suffering',
#   'press',
#   'conference',
#   'message',
#   'president',
#   'meeting',
#   'putin',
#   'spokesman',
#   'dmitry',
#   'peskov',
#   'office',
#   'peace',
#   'initiative',
#   'time',
#   'africa',
#   'resolution',
#   'conflict',
#   'continent',
#   'group',
#   'state',
#   'government',
#   'attempt',
#   'path',
#   'peace',
#   'invasion',
#   'invasion',
#   'ramaphosa',
#   'end',
#   'conflict'],
#  'african-players-nba-basketball-africa-league-spt-spc-intl': ['march',
#   'start',
#   'basketball',
#   'africa',
#   'league',
#   'premier',
#   'basketball',
#   'season',
#   'president',
#   'fall',
#   'rise',
#   'sport',
#   'journey',
#   'competition',
#   'capital',
#   'hometown',
#   'dakar',
#   'feature',
#   'africa',
#   'partnership',
#   'basketball',
#   'federation',
#   'bal',
#   'season',
#   'result',
#   'covid',
#   'pandemic',
#   'place',
#   'culmination',
#   'work',
#   'fall',
#   'quarter',
#   'read',
#   'burna',
#   'boy',
#   'center',
#   'stage',
#   'game',
#   'scholarship',
#   'fall',
#   'seed',
#   'project',
#   'education',
#   'development',
#   'basketball',
#   'platform',
#   'engage',
#   'youth',
#   'leadership',
#   'basketball',
#   'program',
#   'office',
#   'basketball',
#   'africa',
#   'league',
#   'fall',
#   'sport',
#   'opportunity',
#   'pursue',
#   'basketball',
#   'career',
#   'choice',
#   'fall',
#   'start',
#   'season',
#   'toronto',
#   'october',
#   'time',
#   'court',
#   'joel',
#   'embiid',
#   'siakam',
#   'koloko',
#   'part',
#   'basketball',
#   'moment',
#   'basketball',
#   'koloko',
#   'wow',
#   'favorite',
#   'admiration',
#   'player',
#   'mvp',
#   'award',
#   'year',
#   'part',
#   'nba',
#   'survey',
#   'president',
#   'masai',
#   'ujiri',
#   'manager',
#   'championship',
#   'roster',
#   'team',
#   'team',
#   'team',
#   'world',
#   'game',
#   'home',
#   'basketball',
#   'basketball',
#   'create',
#   'ecosystem',
#   'talent',
#   'academy',
#   'africa',
#   'basketball',
#   'training',
#   'center',
#   'saly',
#   'senegal',
#   'something',
#   'achieving',
#   'end',
#   'day',
# ...
#   'regime',
#   'protest',
#   'eiffel',
#   'tower',
#   'week',
#   'call',
#   'intelligence',
#   'activism'],
#  'iran-russia-shipments-caspian-sea-intl-cmd': ['sea',
#   'sea',
#   'route',
#   'path',
#   'iran',
#   'russia',
#   'cargo',
#   'traffic',
#   'cooperation',
#   'sea',
#   'route',
#   'move',
#   'mortar',
#   'government',
#   'regime',
#   'bolster',
#   'war',
#   'effort',
#   'ukraine',
#   'tracking',
#   'region',
#   'movement',
#   'year',
#   'intelligence',
#   'number',
#   'use',
#   'fall',
#   'energy',
#   'infrastructure',
#   'power',
#   'stop',
#   'sea',
#   'capability',
#   'interdict',
#   'intelligence',
#   'analyst',
#   'security',
#   'company',
#   'eos',
#   'risk',
#   'azerbaijan',
#   'kazakhstan',
#   'environment',
#   'trade',
#   'cnn',
#   'comment',
#   'jump',
#   'number',
#   'sea',
#   'number',
#   'data',
#   'list',
#   'phenomenon',
#   'cargo',
#   'weaponry',
#   'bridget',
#   'diakun',
#   'analyst',
#   'reporter',
#   'list',
#   'analysis',
#   'maritime',
#   'maritime',
#   'organization',
#   'resolution',
#   'system',
#   'location',
#   'identification',
#   'information',
#   'safety',
#   'identification',
#   'ais',
#   'tracking',
#   'disguise',
#   'journey',
#   'end',
#   'list',
#   'intelligence',
#   'port',
#   'russia',
#   'sea',
#   'diakun',
#   'ship',
#   'port',
#   'port',
#   'vessel',
#   'cargo',
#   'ship',
#   'port',
#   'cargo',
#   'amirabad',
#   'anzali',
#   'volga',
#   'river',
#   'port',
#   'astrakhan',
#   'list',
#   'marinetraffic',
#   'ship',
#   'maritime',
#   'provider',
#   'cnn',
#   'behavior',
#   'invasion',
#   'journey',
#   'port',
#   'call',
#   'approach',
#   'port',
#   'astrakhan',
#   'port',
#   'imagery',
#   'activity',
#   'sea',
#   'support',
#   'intelligence',
#   'correlation',
#   'russia',
#   'iran',
#   'port',
#   'sea',
#   'increase',
#   'activity',
#   'invasion',
#   'ukraine',
#   'attention',
#   'interest',
#   'sea',
#   'route',
#   'route',
#   'sea',
#   'strengthen',
#   'maritime',
#   'route',
#   'trade',
#   'diakun',
#   'cnn',
#   'trade',
#   'route',
#   'agenda',
#   'azerbaijan',
#   'kazakhstan',
#   'turkmenistan',
#   'trade',
#   'path',
#   'diakun',
#   'hotspot',
#   'consultancy',
#   'bosphorus',
#   'cnn',
#   'regime',
#   'port',
#   'war',
#   'bolster',
#   'shipping',
#   'route',
#   'iran',
#   'project',
#   'river',
#   'bosphorus',
#   'observer',
#   'port',
#   'sea',
#   'week',
#   'putin',
#   'counterpart',
#   'ebrahim',
#   'raisi',
#   'deal',
#   'finance',
#   'build',
#   'railway',
#   'line',
#   'part',
#   'transport',
#   'artery',
#   'putin',
#   'railway',
#   'branch',
#   'sea',
#   'sea',
#   'ocean',
#   'gulf',
#   'bolster',
#   'trade',
#   'administration',
#   'iran',
#   'improvement',
#   'russia',
#   'bassiri',
#   'tabrizi',
#   'head',
#   'program',
#   'royal',
#   'institute',
#   'rusi',
#   'balance',
#   'power',
#   'february',
#   'year',
#   'provider',
#   'weapon',
#   'capability',
#   'war',
#   'number',
#   'russia',
#   'year',
#   'challenge',
#   'country',
#   'tabrizi',
#   'environment',
#   'number',
#   'perception',
#   'moscow',
#   'iran',
#   'russia',
#   'lot',
#   'economy',
#   'march',
#   'finance',
#   'minister',
#   'define',
#   'violation',
#   'security',
#   'council',
#   'resolution',
#   'iran',
#   'deal',
#   'control',
#   'transfer',
#   'sanction',
#   'bosphorus',
#   'observer',
#   'analyst',
#   'yörük',
#   'işık',
#   'russia',
#   'equipment',
#   'iran',
#   'sea',
#   'route',
#   'enhance',
#   'enforcement',
#   'access',
#   'january',
#   'security',
#   'council',
#   'spokesperson',
#   'adrienne',
#   'watson',
#   'statement',
#   'target',
#   'production',
#   'export',
#   'april',
#   'vice',
#   'brad',
#   'cooper',
#   'command',
#   'fleet',
#   'meet',
#   'region',
#   'innovation',
#   'enhance',
#   'maritime',
#   'security',
#   'fleet',
#   'spokesperson',
#   'tim',
#   'iran',
#   'security',
#   'air',
#   'moscow',
#   'march',
#   'statement',
#   'resistance',
#   'center',
#   'ukraine',
#   'treasury',
#   'department',
#   'air',
#   'year',
#   'department',
#   'cargo',
#   'russia',
#   'violation',
#   'export',
#   'statement',
#   'support',
#   'aircraft',
#   'export',
#   'support',
#   'war',
#   'machine',
#   'provisioning',
#   'cnn',
#   'cargo',
#   'march',
#   'state',
#   'iran',
#   'russia',
#   'risk',
#   'group',
#   'volume',
#   'voyage',
#   'ship',
#   'volume',
#   'november',
#   'regime',
#   'number',
#   'russia',
#   'minister',
#   'war',
#   'iran',
#   'sale',
#   'violate',
#   'russia',
#   'presidency',
#   'security',
#   'council',
#   'april',
#   'scoff',
#   'ministry',
#   'spokesperson',
#   'maria',
#   'year',
#   'country',
#   'evidence',
#   'use',
#   'activity',
#   'port',
#   'sea',
#   'inland',
#   'body',
#   'water',
#   'authority',
#   'hide',
#   'ship',
#   'layer',
#   'protection',
#   'region',
#   'cooperation',
#   'inland',
#   'sea',
#   'influence',
#   'interference',
#   'strength',
#   'moscow',
#   'sea',
#   'theater',
#   'confrontation',
#   'russia',
#   'iran',
#   'avenue',
#   'sanction',
#   'evasion',
#   'weapon',
#   'provision',
#   'tabrizi',
#   'partnership',
#   'front',
#   'east',
#   'watch',
#   'iran',
#   'drone',
#   'tabrizi'],
#  'iranian-chess-referee-shohreh-bayat-russia-spt-intl': ['iran',
#   'bayat',
#   'body',
#   'president',
#   'deputy',
#   'minister',
#   'choice',
#   'clothing',
#   'tournament',
#   'iran',
#   'headscarf',
#   'world',
#   'chess',
#   'championship',
#   'china',
#   'pressure',
#   'result',
#   'home',
#   'fear',
#   'bayat',
#   'federation',
#   'president',
#   'support',
#   'bayat',
#   'husband',
#   'fischer',
#   'world',
#   'chess',
#   'championship',
#   'reykjavik',
#   'iceland',
#   'tournament',
#   'opportunity',
#   'bayat',
#   'time',
#   'home',
#   'country',
#   'death',
#   'mahsa',
#   'woman',
#   'morality',
#   'police',
#   'dress',
#   'code',
#   'outrage',
#   'range',
#   'story',
#   'bayat',
#   'stand',
#   'motto',
#   'stand',
#   'bayat',
#   'day',
#   'official',
#   'statement',
#   'cnn',
#   'fide',
#   'dress',
#   'decor',
#   'bayat',
#   'bayat',
#   'handbook',
#   'dress',
#   'code',
#   'event',
#   'dress',
#   'image',
#   'chess',
#   'cnn',
#   'dress',
#   'code',
#   'request',
#   'stop',
#   'wearing',
#   'slogan',
#   'bayat',
#   'breaking',
#   'bayat',
#   'take',
#   'time',
#   'request',
#   'president',
#   'arkady',
#   'dvorkovich',
#   'minister',
#   'bayat',
#   'person',
#   'room',
#   'dvorkovich',
#   'cnn',
#   'request',
#   'bayat',
#   'request',
#   'bayat',
#   'bayat',
#   'dvorkovich',
#   'day',
#   'charter',
#   'promote',
#   'protection',
#   'bayat',
#   'arkady',
#   'bayat',
#   'fide',
#   'stand',
#   'notion',
#   'part',
#   'request',
#   'activism',
#   'moment',
#   'chose',
#   'day',
#   'bayat',
#   'outfit',
#   'support',
#   'invasion',
#   'memory',
#   'iran',
#   'plane',
#   'tehran',
#   'nothing',
#   'outfit',
#   'tournament',
#   'iceland',
#   'bayat',
#   'cnn',
#   'fide',
#   'event',
#   'organization',
#   'arbiter',
#   'bayat',
#   'commission',
#   'registry',
#   'message',
#   'cnn',
#   'fide',
#   'official',
#   'name',
#   'database',
#   'fide',
#   'cnn',
#   'bayat',
#   'contention',
#   'world',
#   'president',
#   'dvorkovich',
#   'term',
#   'minister',
#   'stint',
#   'kremlin',
#   'fide',
#   'president',
#   'year',
#   'proximity',
#   'kremlin',
#   'work',
#   'establishment',
#   'question',
#   'war',
#   'cnn',
#   'criticism',
#   'iran',
#   'country',
#   'iran',
#   'support',
#   'russia',
#   'aid',
#   'war',
#   'chess',
#   'federation',
#   'evidence',
#   'letter',
#   'iran',
#   'comply',
#   'president',
#   'chess',
#   'federation',
#   'iran',
#   'compliance',
#   'warning',
#   'concrete',
#   'fide',
#   'chess',
#   'federation',
#   'silent',
#   'eye',
#   'pressure',
#   'support',
#   'fide',
#   'absolute',
#   'faith',
#   'respect',
#   'stance',
#   'fide',
#   'neutrality',
#   'duty',
#   'hold',
#   'integrity',
#   'neutrality',
#   'discretion',
#   'fide',
#   'statement',
#   'matter',
#   'cause',
#   'activism',
#   'role',
#   'arbiter',
#   'activism',
#   'attention',
#   'chess',
#   'referee',
#   'nakamura',
#   'response',
#   'message',
#   'chess',
#   'superstar',
#   'magnus',
#   'coach',
#   'peter',
#   'heine',
#   'chess',
#   'world',
#   'side',
#   'bayat',
#   'chess',
#   'support',
#   'asylum',
#   'england',
#   'support',
#   'see',
#   'thing'],
#  'iranian-chess-sara-khadem-spanish-prime-minister-spt-intl': ['minister',
#   'pedro',
#   'sánchez',
#   'chess',
#   'player',
#   'sara',
#   'khadem',
#   'part',
#   'tournament',
#   'khadem',
#   'sarasadat',
#   'khademalsharieh',
#   'spain',
#   'wednesday',
#   'pair',
#   'meeting',
#   'khadem',
#   'today',
#   'woman',
#   'chess',
#   'grandmaster',
#   'sara',
#   'khadem',
#   'support',
#   'example',
#   'december',
#   'khadem',
#   'outlet',
#   'jamaran',
#   'hijab',
#   'dress',
#   'code',
#   'participation',
#   'fide',
#   'world',
#   'rapid',
#   'blitz',
#   'chess',
#   'khadem',
#   'player',
#   'iran',
#   'number',
#   'event',
#   'hijab',
#   'september',
#   'death',
#   'mahsa',
#   'woman',
#   'morality',
#   'police',
#   'dress',
#   'code',
#   'outrage',
#   'range',
#   'climber',
#   'elnaz',
#   'rekabi',
#   'korea',
#   'hijab',
#   'november',
#   'archer',
#   'parmida',
#   'ghasemi',
#   'support',
#   'hijab',
#   'ceremony',
#   'tehran',
#   'notice',
#   'deputy',
#   'minister',
#   'kazemipour',
#   'opportunity',
#   'chess',
#   'referee',
#   'shohreh',
#   'bayat',
#   'iran',
#   'headscarf',
#   'world',
#   'chess',
#   'championship',
#   'china',
#   'pressure',
#   'result',
#   'home',
#   'fear',
#   'interview',
#   'newspaper',
#   'país',
#   'khadem',
#   'reason',
#   'hijab',
#   'tournament',
#   'honest',
#   'tournament',
#   'hijab',
#   'mean',
#   'somehow',
#   'feel',
#   'cnn',
#   'instagram'],
#  'iraq-gulf-cup-comeback-mime-intl': ['iraq',
#   'soccer',
#   'tournament',
#   'gulf',
#   'competition',
#   'deadlock',
#   'tournament',
#   'hope',
#   'population',
#   'message',
#   'iraq',
#   'world',
#   'move',
#   'isolation',
#   'iraqis',
#   'gulf',
#   'cup',
#   'tournament',
#   'something',
#   'country',
#   'osgood',
#   'director',
#   'control',
#   'consultancy',
#   'firm',
#   'time',
#   'iraq',
#   'cup',
#   'capital',
#   'time',
#   'port',
#   'city',
#   'basra',
#   'oman',
#   'kuwait',
#   'qatar',
#   'bahrain',
#   'cup',
#   'nation',
#   'regime',
#   'change',
#   'occupation',
#   'insurgency',
#   'basra',
#   'rest',
#   'energy',
#   'food',
#   'effect',
#   'city',
#   'need',
#   'investment',
#   'osgood',
#   'participate',
#   'exercise',
#   'excitement',
#   'fervor',
#   'basra',
#   'nation',
#   'moment',
#   'ali',
#   'taxi',
#   'driver',
#   'basra',
#   'city',
#   'joy',
#   'cup',
#   'gulf',
#   'country',
#   'government',
#   'saudi',
#   'arabia',
#   'government',
#   'permission',
#   'travel',
#   'iraq',
#   'saad',
#   'maan',
#   'ministry',
#   'cnn',
#   'security',
#   'assure',
#   'safety',
#   'stability',
#   'baghdad',
#   'university',
#   'head',
#   'security',
#   'situation',
#   'security',
#   'iraq',
#   'event',
#   'bolster',
#   'image',
#   'saddam',
#   'invasion',
#   'opening',
#   'ceremony',
#   'friday',
#   'performance',
#   'history',
#   'occasion',
#   'iraqi',
#   'football',
#   'association',
#   'kuwait',
#   'brawl',
#   'place',
#   'basra',
#   'vip',
#   'section',
#   'representative',
#   'delegation',
#   'kuwait',
#   'participation',
#   'tournament',
#   'security',
#   'chaos',
#   'invasion',
#   'ruler',
#   'saddam',
#   'hussein',
#   'end',
#   'stalemate',
#   'deadlock',
#   'election',
#   'president',
#   'premier',
#   'government',
#   'prevent',
#   'stability',
#   'economy',
#   'crisis',
#   'infrastructure',
#   'iran',
#   'center',
#   'violence',
#   'basra',
#   'city',
#   'security',
#   'crime',
#   'protest',
#   'activity',
#   'osgood',
#   'issue',
#   'prohibitive',
#   'government',
#   'security',
#   'provision',
#   'mitigate',
#   'balance',
#   'security',
#   'disruption',
#   'tournament',
#   'unrest',
#   'goodwill',
#   'spoil',
#   'soccer',
#   'radar',
#   'topic',
#   'gulf',
#   'region',
#   'iraq',
#   'cup',
#   'nation',
#   'decade',
#   'saddam',
#   'invasion',
#   'kuwait',
#   'hosting',
#   'security',
#   'tournament',
#   'basra',
#   'gulf',
#   'iraq',
#   'ali',
#   'salman',
#   'iraq',
#   'rent',
#   'karate',
#   'champion',
#   'volunteer',
#   'coach',
#   'connection',
#   'outrage',
#   'union',
#   'statement',
#   'saturday',
#   'sign',
#   'repression',
#   'sweden',
#   'meet',
#   'turkey',
#   'application',
#   'join',
#   'alliance',
#   'support',
#   'minister',
#   'give',
#   'minister',
#   'ulf',
#   'defence',
#   'conference',
#   'cemetery',
#   'vandalism',
#   'police',
#   'cemetery',
#   'mount',
#   'zion',
#   'israel',
#   'judge',
#   'decide',
#   'extension',
#   'detention',
#   'arrest',
#   'investigation',
#   'justice',
#   'statement',
#   'police',
#   'spokesperson',
#   'jerusalem',
#   'bid',
#   'farewell',
#   'era',
#   'literature',
#   'brexit',
#   'saqi',
#   'bookstore',
#   'bookstore',
#   'saqi',
#   'water',
#   'seller',
#   'arabic',
#   'mai',
#   'war',
#   'shop',
#   'collection',
#   'english',
#   'publishing',
#   'house',
#   'london',
#   'beirut',
#   'home',
#   'daughter',
#   'publisher',
#   'lynn',
#   'gaspard',
#   'bbc',
#   'city',
#   'refuge',
#   'war',
#   'turmoil',
#   'hub',
#   'summer',
#   'place',
#   'east',
#   'london',
#   'stock',
#   'door',
#   'legacy',
#   'masoud',
#   'bookseller',
#   'store',
#   'initiative',
#   'maqam',
#   'content',
#   'belonging'],
#  'ireland-abortion-referendum-5-years-intl-cmd': ['public',
#   'amendment',
#   'abortion',
#   'jubilation',
#   'result',
#   'step',
#   'abortion',
#   'pregnancy',
#   'risk',
#   'life',
#   'fetus',
#   'abortion',
#   'system',
#   'system',
#   'number',
#   'year',
#   'smyth',
#   'activist',
#   'repeal',
#   'woman',
#   'abortion',
#   'edge',
#   'limit',
#   'cnn',
#   'felt',
#   'process',
#   'feel',
#   'felt',
#   'miscarriage',
#   'abortion',
#   'country',
#   'woman',
#   'cnn',
#   'call',
#   'sarah',
#   'report',
#   'government',
#   'month',
#   'availability',
#   'abortion',
#   'introduction',
#   'access',
#   'abortion',
#   'ireland',
#   'lottery',
#   'review',
#   'barrister',
#   'marie',
#   'country',
#   'coverage',
#   'report',
#   'gps',
#   'orla',
#   'director',
#   'council',
#   'ireland',
#   'cnn',
#   'abuse',
#   'response',
#   'request',
#   'comment',
#   'access',
#   'abortion',
#   'department',
#   'health',
#   'landmark',
#   'day',
#   'rollout',
#   'termination',
#   'pregnancy',
#   'statement',
#   'press',
#   'office',
#   'minister',
#   'health',
#   'effect',
#   'decision',
#   'review',
#   'anniversary',
#   'place',
#   'home',
#   'forefront',
#   'campaign',
#   'amendment',
#   'abortion',
#   'ireland',
#   'life',
#   'abortion',
#   'part',
#   'healthcare',
#   'result',
#   'work',
#   'strike',
#   'action',
#   'abortion',
#   'england',
#   'year',
#   'something',
#   'secrecy',
#   'cnn',
#   'call',
#   'reform',
#   'ban',
#   'death',
#   'woman',
#   'halappanavar',
#   'abortion',
#   'county',
#   'galway',
#   'hospital',
#   'consciousness',
#   'anybody',
#   'hospital',
#   'unwell',
#   'camilla',
#   'associate',
#   'professor',
#   'university',
#   'maynooth',
#   'history',
#   'abortion',
#   'time',
#   'vote',
#   'sense',
#   'abortion',
#   'ban',
#   'society',
#   'decision',
#   'smyth',
#   'referendum',
#   'president',
#   'amendment',
#   'legislation',
#   'vote',
#   'number',
#   'access',
#   'abortion',
#   'legislation',
#   'period',
#   'consultation',
#   'access',
#   'abortion',
#   'medication',
#   'sarah',
#   'cnn',
#   'case',
#   'period',
#   'measure',
#   'scrap',
#   'impact',
#   'ireland',
#   'report',
#   'cost',
#   'burden',
#   'income',
#   'example',
#   'service',
#   'euro',
#   'petrol',
#   'pandemic',
#   'government',
#   'consultation',
#   'phone',
#   'report',
#   'author',
#   'lorraine',
#   'appointment',
#   'person',
#   'procedure',
#   'part',
#   'abortion',
#   'coverage',
#   'perfect',
#   'situation',
#   'maternity',
#   'present',
#   'maternity',
#   'country',
#   'abortion',
#   'report',
#   'expansion',
#   'maternity',
#   'provision',
#   'law',
#   'abortion',
#   'part',
#   'proportion',
#   'health',
#   'service',
#   'cnn',
#   'abortion',
#   'abortion',
#   'training',
#   'curricula',
#   'support',
#   'recommendation',
#   'training',
#   'obstacle',
#   'provision',
#   'person',
#   'abortion',
#   'limit',
#   'limit',
#   'woman',
#   'limit',
#   'weekend',
#   'holiday',
#   'difficulty',
#   'appointment',
#   'care',
#   'abortion',
#   'ireland',
#   'case',
#   'abnormality',
#   'example',
#   'baby',
#   'abortion',
#   'ask',
#   'abortion',
#   'abortion',
#   'time',
#   'limit',
#   'sarah',
#   'fearing',
#   'continue',
#   'procedure',
#   'maternity',
#   'hospital',
#   'sarah',
#   'sense',
#   'anger',
#   'practitioner',
#   'somebody',
#   'mine',
#   'choice',
#   'backdrop',
#   'abortion',
#   'health',
#   'service',
#   'review',
#   'abortion',
#   'travel',
#   'need',
#   'instance',
#   'woman',
#   'country',
#   'access',
#   'health',
#   'care',
#   'failure',
#   'health',
#   'system',
#   'focusing',
#   'government',
#   'health',
#   'committee',
#   'review',
#   'statement',
#   'cnn',
#   'department',
#   'health',
#   'health',
#   'service',
#   'executive',
#   'healthcare',
#   'system',
#   'committee',
#   'health',
#   'change',
#   'wednesday',
#   'council',
#   'campaign',
#   'commitment',
#   'reform',
#   'press',
#   'abortion',
#   'access',
#   'provision',
#   'abortion',
#   'sarah',
#   'cnn',
#   'decision',
#   'abortion',
#   'guilt',
#   'stigma',
#   'abortion'],
#  ...}

# %%
noun_frequency = dict()

# %%
for article_nouns in articles.values():
    for noun in set(article_nouns):
        if not noun_frequency.get(noun):
            noun_frequency[noun] = 1
        else:
            noun_frequency[noun] += 1

# %%
# How many word-articles count dictionary
noun_frequency
# Out:
# {'body': 333,
#  'iskander': 13,
#  'brother': 109,
#  'strike': 190,
#  'support': 621,
#  'state': 750,
#  'volodymyr': 175,
#  'dust': 19,
#  'friday': 307,
#  'border': 148,
#  'russia': 504,
#  'war': 607,
#  'federation': 192,
#  'kuleba': 15,
#  'picture': 104,
#  'result': 275,
#  'grocery': 7,
#  'store': 32,
#  'day': 800,
#  'ministry': 350,
#  'sense': 134,
#  'administration': 130,
#  'chief': 186,
#  'prosecutor': 90,
#  'olena': 6,
#  'reach': 183,
#  'morning': 267,
#  'blanket': 11,
#  'cruel': 19,
#  'kharkiv': 37,
#  'defense': 499,
#  'address': 105,
#  'hroza': 6,
#  'child': 109,
#  'region': 330,
#  'lady': 20,
#  'dmitro': 1,
#  'boy': 57,
#  'missile': 120,
#  'president': 864,
#  'severity': 19,
#  'grandmother': 16,
#  'october': 80,
#  'attack': 301,
#  'show': 269,
#  'city': 740,
#  'thursday': 340,
#  'cafe': 8,
#  'minister': 584,
#  'village': 121,
#  'information': 268,
#  'evidence': 225,
#  'round': 312,
#  'group': 646,
#  'fleet': 46,
#  'half': 273,
#  'replacement': 19,
#  'fighting': 52,
#  'blast': 37,
#  'moscow': 239,
#  'source': 138,
#  'storage': 27,
#  'monitoring': 27,
#  'analyst': 71,
#  'fight': 191,
#  'front': 185,
#  'ukraine': 414,
#  'amount': 129,
#  'term': 95,
#  'germany': 159,
#  'action': 284,
#  'tank': 72,
#  'intelligence': 148,
#  'month': 481,
#  'cover': 58,
#  'paper': 44,
#  'chance': 277,
#  'website': 88,
#  'force': 293,
#  'oryx': 5,
#  'fraction': 7,
#  'technology': 66,
#  'design': 25,
#  'battle': 221,
#  'janovsky': 2,
#  'week': 725,
#  'infantry': 44,
#  'focus': 150,
#  'toll': 57,
#  'reactivate': 1,
#  'figure': 139,
#  'ammunition': 96,
#  'flaw': 1,
#  'equipment': 132,
#  'sent': 30,
#  'invasion': 335,
#  'count': 48,
#  'armor': 31,
#  'jakub': 5,
#  'way': 846,
#  'territory': 190,
#  'caricature': 2,
#  'akbar': 1,
#  'religion': 32,
#  'airport': 43,
#  'afternoon': 86,
#  'madrid': 68,
#  'ceremony': 99,
#  'part': 874,
#  'cherif': 1,
#  'woman': 256,
#  'assault': 156,
#  'suburb': 24,
#  'police': 400,
#  'aqap': 1,
#  'food': 133,
#  'warrant': 20,
#  'ticket': 48,
#  'affiliate': 125,
#  'cartoon': 3,
#  'financing': 5,
#  'gunman': 8,
#  'authority': 96,
#  'francois': 5,
#  'bulgaria': 12,
#  'decision': 483,
#  'gas': 99,
#  'légion': 1,
#  'indict': 1,
#  'coulibaly': 2,
#  'standoff': 8,
#  'angela': 14,
#  'time': 1649,
#  'lack': 109,
#  'islamist': 5,
#  'suis': 1,
#  'vest': 5,
#  'maintenance': 25,
#  'peninsula': 50,
#  'bfmtv': 32,
#  'operation': 185,
#  'sign': 158,
#  'girlfriend': 20,
#  'list': 152,
#  'course': 401,
#  'serving': 4,
#  'tower': 13,
#  'northeast': 14,
#  'magazine': 30,
#  'david': 79,
#  'arrest': 134,
#  'kosher': 1,
#  'december': 172,
#  'law': 284,
#  'order': 277,
#  'bulletproof': 1,
#  'edition': 67,
#  'briefly': 48,
#  'istanbul': 16,
#  'amedy': 1,
#  'muslim': 16,
#  'name': 277,
#  'launch': 52,
#  'enforcement': 58,
#  'plot': 20,
#  'flight': 89,
#  'building': 136,
#  'march': 380,
#  'look': 219,
#  'court': 451,
#  'gasoline': 3,
#  'eiffel': 3,
#  'porte': 1,
#  'terror': 50,
#  'terrorism': 47,
#  'officer': 135,
#  'prefecture': 10,
#  'title': 355,
#  'responsibility': 115,
#  'remembrance': 13,
#  'wife': 199,
#  'newspaper': 100,
#  'station': 91,
#  'hebdomadaire': 1,
#  'investigation': 310,
#  'terrorist': 29,
#  'netanyahu': 1,
#  'street': 129,
#  'subway': 5,
#  'cameron': 23,
#  'evening': 78,
#  'death': 292,
#  'phrase': 17,
#  'kouachi': 1,
#  'hollande': 2,
#  'honor': 64,
#  'benjamin': 11,
#  'boumeddiene': 1,
#  'face': 351,
#  'chancellor': 44,
#  'merkel': 8,
#  'goal': 343,
#  'security': 430,
#  'absentia': 8,
#  'area': 316,
#  'bomb': 44,
#  'hebdo': 4,
#  'official': 191,
#  'publication': 27,
#  'accomplice': 2,
#  'return': 256,
#  'france': 197,
#  'world': 1208,
#  'charlie': 8,
#  'paris': 93,
#  'worker': 28,
#  'phone': 111,
#  'prophet': 2,
#  'connection': 68,
#  'dream': 117,
#  'gonzaga': 4,
#  'point': 422,
#  'darrion': 3,
#  'kind': 324,
#  'diego': 40,
#  'foul': 22,
#  'university': 311,
#  'exhilaration': 1,
#  'story': 192,
#  'cinderella': 7,
#  'dutcher': 2,
#  'head': 573,
#  'team': 1079,
#  'culmination': 10,
#  'championship': 290,
#  'loss': 247,
#  'aztecs': 3,
#  'year': 1185,
#  'margin': 25,
#  'none': 76,
#  'foe': 4,
#  'competition': 182,
#  'experience': 201,
#  'sanogo': 3,
#  'positivity': 8,
#  'form': 203,
#  'appearance': 154,
#  'guard': 126,
#  'college': 133,
#  'florida': 55,
#  'basket': 17,
#  'suffering': 26,
#  'something': 509,
#  'feel': 229,
#  'trophy': 122,
#  'set': 130,
#  'bracket': 14,
#  'madness': 34,
#  'expectation': 17,
#  'sunday': 338,
#  'brian': 16,
#  'miami': 93,
#  'hand': 198,
#  'corner': 68,
#  'win': 448,
#  'seed': 100,
#  'martin': 43,
#  'larrañaga': 1,
#  'call': 176,
#  'practice': 135,
#  'dickinson': 7,
#  'memphis': 25,
#  'basketball': 171,
#  'game': 884,
#  'creighton': 8,
#  'love': 141,
#  'tournament': 342,
#  'fifth': 34,
#  'pressure': 254,
#  'side': 392,
#  'nation': 164,
#  'tennessee': 22,
#  'attitude': 39,
#  'tipoff': 1,
#  'run': 185,
#  'jim': 25,
#  'coach': 403,
#  'step': 217,
#  'place': 737,
#  'fau': 2,
#  'victory': 555,
#  'texas': 50,
#  'alijah': 1,
#  'kansas': 23,
#  'season': 672,
#  'alabama': 23,
#  'play': 511,
#  'hip': 13,
#  'rolling': 5,
#  'home': 683,
#  'minute': 130,
#  'trammell': 3,
#  'end': 544,
#  'australia': 99,
#  'houston': 50,
#  'tune': 16,
#  'carter': 12,
#  'floor': 84,
#  'draft': 119,
#  'member': 321,
#  'program': 175,
#  'keep': 42,
#  'class': 57,
#  'football': 464,
#  'community': 235,
#  'selection': 37,
#  'buffalo': 62,
#  'start': 309,
#  'spring': 86,
#  'indianapolis': 21,
#  'teams': 4,
#  'carolina': 44,
#  'rusher': 5,
#  'plenty': 49,
#  'suv': 7,
#  'pittsburgh': 17,
#  'lecroy': 4,
#  'brock': 12,
#  'ambition': 25,
#  'native': 9,
#  'campus': 23,
#  'champion': 399,
#  'levis': 3,
#  'edge': 59,
#  'willock': 6,
#  'speed': 76,
#  'porter': 9,
#  'star': 372,
#  'georgia': 37,
#  'injury': 208,
#  'rise': 83,
#  'fox': 19,
#  'philadelphia': 79,
#  'journey': 111,
#  'tackle': 56,
#  'service': 316,
#  'africa': 50,
#  'need': 153,
#  'predict': 7,
#  'anthony': 60,
#  'backfield': 1,
#  'super': 75,
#  'york': 209,
#  'bay': 74,
#  'strength': 82,
#  'placement': 4,
#  'power': 343,
#  'famer': 26,
#  'demeanor': 4,
#  'lead': 254,
#  'lance': 14,
#  'gonzalez': 4,
#  'consideration': 24,
#  'line': 351,
#  'player': 664,
#  'jalen': 28,
#  'ford': 10,
#  'los': 134,
#  'ball': 181,
#  'number': 548,
#  'moore': 11,
#  'cam': 8,
#  'standout': 19,
#  'level': 317,
#  'penn': 6,
#  'driving': 17,
#  'snap': 9,
#  'probation': 12,
#  'fine': 23,
#  'pass': 128,
#  'knock': 14,
#  'headline': 12,
#  'england': 204,
#  'staff': 283,
#  'moniker': 15,
#  'network': 105,
#  'role': 324,
#  'devin': 14,
#  'abc': 16,
#  'opportunity': 286,
#  'field': 330,
#  'tape': 14,
#  'pleas': 2,
#  'starter': 19,
#  'ceiling': 11,
#  'jail': 54,
#  'california': 77,
#  'ability': 161,
#  'franchise': 61,
#  'everything': 426,
#  'sustain': 17,
#  'celebrate': 52,
#  'quarterback': 95,
#  'joy': 57,
#  'eye': 70,
#  'atop': 5,
#  'particular': 11,
#  'rtl': 5,
#  'crash': 73,
#  'vehicle': 84,
#  'road': 176,
#  'reader': 3,
#  'bowl': 126,
#  'mexico': 39,
#  'fill': 12,
#  'potential': 25,
#  'baltimore': 23,
#  'nfl': 128,
#  'anderson': 32,
#  'combination': 62,
#  'jacksonville': 20,
#  'decline': 22,
#  'serve': 41,
#  'espn': 72,
#  'receiver': 33,
#  'trading': 4,
#  'prospect': 30,
#  'tabs': 3,
#  'build': 39,
#  'witherspoon': 3,
#  'richardson': 10,
#  'stock': 21,
#  'branch': 28,
#  'defeat': 173,
#  'missouri': 10,
#  'life': 513,
#  'teammate': 102,
#  'devon': 3,
#  'washington': 90,
#  'pick': 107,
#  'watch': 147,
#  'chandler': 7,
#  'county': 51,
#  'joey': 5,
#  'success': 239,
#  'seahawks': 13,
#  'contact': 85,
#  'talent': 72,
#  'purdy': 9,
#  'defensive': 30,
#  'rule': 112,
#  'caller': 4,
#  'bryce': 8,
#  'projection': 3,
#  'july': 184,
#  'panel': 29,
#  'payment': 28,
#  'promote': 22,
#  'duty': 51,
#  'gianni': 25,
#  'geneva': 7,
#  'obligation': 12,
#  'headquarters': 41,
#  'undersell': 1,
#  'fifa': 73,
#  'cup': 408,
#  'spain': 133,
#  'event': 353,
#  'broadcast': 72,
#  'fair': 16,
#  'price': 58,
#  'money': 224,
#  'qatar': 52,
#  'organization': 284,
#  'discussion': 45,
#  'italy': 82,
#  'therefore': 12,
#  'statement': 850,
#  'sport': 383,
#  'portion': 20,
#  'taking': 6,
#  'development': 116,
#  'trade': 100,
#  'infantino': 25,
#  'semifinalist': 2,
#  'june': 240,
#  'rally': 37,
#  'nelson': 13,
#  'richmond': 4,
#  'attempt': 145,
#  'send': 38,
#  'water': 175,
#  'rapture': 1,
#  'neither': 2,
#  'cain': 2,
#  'tennis': 166,
#  'simone': 14,
#  'frediani': 1,
#  'jason': 39,
#  'john': 131,
#  'record': 502,
#  'inch': 11,
#  'clash': 51,
#  'kubler': 1,
#  'daniele': 3,
#  'exchange': 63,
#  'match': 414,
#  'gaël': 2,
#  'break': 165,
#  'winner': 295,
#  'tension': 38,
#  'favorite': 33,
#  'pecci': 1,
#  'crowd': 128,
#  'jean': 9,
#  'hepner': 1,
#  'backhand': 7,
#  'virginia': 31,
#  'mistake': 49,
#  'rest': 174,
#  'moncada': 1,
#  'mlb': 40,
#  'come': 64,
#  'catch': 39,
#  'fence': 18,
#  'aaron': 40,
#  'judge': 88,
#  'toe': 6,
#  'bit': 200,
#  'detroit': 10,
#  'monday': 349,
#  'martinez': 16,
#  'probability': 11,
#  'benintendi': 1,
#  'hendriks': 5,
#  'manager': 249,
#  'wall': 52,
#  'stranger': 22,
#  'finale': 13,
#  'adversity': 16,
#  'mri': 7,
#  'cancer': 50,
#  'tim': 26,
#  'saturday': 323,
#  'burger': 3,
#  'momentum': 69,
#  'right': 92,
#  'chicago': 38,
#  'bat': 11,
#  'boone': 2,
#  'drive': 75,
#  'jake': 18,
#  'host': 138,
#  'heart': 208,
#  'moment': 434,
#  'fact': 253,
#  'sure': 41,
#  'throw': 36,
#  'mound': 6,
#  'today': 312,
#  'bullpen': 2,
#  'yoan': 1,
#  'okay': 14,
#  'slam': 141,
#  'hit': 105,
#  'diagnosis': 26,
#  'series': 337,
#  'thing': 312,
#  'door': 68,
#  'spot': 146,
#  'offseason': 27,
#  'display': 71,
#  'stadium': 256,
#  'homer': 5,
#  'pitch': 140,
#  'cole': 14,
#  'chore': 1,
#  'captain': 103,
#  'guy': 87,
#  'process': 242,
#  'center': 329,
#  'roar': 7,
#  'plate': 17,
#  'ballpark': 6,
#  'francisco': 39,
#  'soak': 5,
#  'gerrit': 1,
#  'deal': 273,
#  'webb': 4,
#  'baseball': 73,
#  'family': 548,
#  'let': 85,
#  'remain': 20,
#  'contract': 147,
#  'san': 24,
#  'top': 96,
#  'berkeley': 5,
#  'isolation': 24,
#  'purpose': 20,
#  'realize': 15,
#  'news': 497,
#  'interest': 111,
#  'career': 385,
#  'surrender': 15,
#  'entail': 1,
#  'peace': 122,
#  'departure': 40,
#  'happiness': 15,
#  'mind': 92,
#  'extension': 42,
#  'dimethyltryptamine': 3,
#  'uncertainty': 30,
#  'work': 539,
#  'medicine': 34,
#  'tuesday': 353,
#  'judgment': 24,
#  'healing': 1,
#  'drug': 47,
#  'film': 62,
#  'darkness': 20,
#  'dmt': 3,
#  'meditation': 3,
#  'headspace': 3,
#  'perspective': 36,
#  'trip': 135,
#  'gon': 30,
#  'mcafee': 7,
#  'speculation': 67,
#  'eat': 29,
#  'produce': 21,
#  'retreat': 22,
#  'mvp': 97,
#  'finality': 3,
#  'marcus': 17,
#  'tell': 72,
#  'someone': 213,
#  'diva': 1,
#  'remember': 29,
#  'drag': 6,
#  'interview': 308,
#  'aubrey': 1,
#  'anybody': 32,
#  'everybody': 108,
#  'whatever': 11,
#  'drama': 51,
#  'sooner': 8,
#  'favre': 3,
#  'brett': 14,
#  'chapter': 38,
#  'walking': 11,
#  'hall': 103,
#  'say': 19,
#  'namath': 3,
#  'saleh': 6,
#  'couple': 129,
#  'broadway': 2,
#  'choice': 76,
#  'robert': 41,
#  'press': 336,
#  'douglas': 2,
#  'xlv': 1,
#  'jersey': 64,
#  'joe': 137,
#  'duration': 8,
#  'direction': 104,
#  'conference': 352,
#  'mention': 35,
#  'surreal': 9,
#  'facility': 102,
#  'bone': 17,
#  'gratitude': 26,
#  'osteosarcoma': 1,
#  'ghent': 1,
#  'gutekunst': 2,
#  'making': 29,
#  'announce': 48,
#  'culture': 125,
#  'thank': 90,
#  'recipient': 15,
#  'character': 33,
#  'dialogue': 23,
#  'get': 292,
#  'caliber': 4,
#  'select': 5,
#  'schefter': 5,
#  'tibia': 2,
#  'night': 386,
#  'instagram': 71,
#  'wisconsin': 3,
#  'oregon': 9,
#  'bitterness': 1,
#  'intention': 60,
#  'league': 492,
#  'packer': 4,
#  'pat': 24,
#  'move': 309,
#  'reality': 98,
#  'wednesday': 369,
#  'matter': 231,
#  'think': 203,
#  'professional': 38,
#  'continue': 96,
#  'appreciation': 23,
#  'situation': 353,
#  'route': 90,
#  'silence': 54,
#  'lot': 520,
#  'psychedelic': 1,
#  'retirement': 76,
#  'walk': 48,
#  'hello': 3,
#  'bumper': 1,
#  'profound': 12,
#  'path': 91,
#  'drink': 10,
#  'glory': 34,
#  'spend': 8,
#  'accuracy': 18,
#  'study': 94,
#  'overtime': 20,
#  'talk': 158,
#  'locker': 64,
#  'mad': 9,
#  'schedule': 58,
#  'void': 6,
#  'coaster': 6,
#  'reaction': 75,
#  'wilson': 25,
#  'difference': 83,
#  'fan': 145,
#  'grass': 27,
#  'emotion': 52,
#  'message': 204,
#  'imagine': 43,
#  'jeff': 13,
#  'use': 306,
#  'roller': 6,
#  'zach': 13,
#  'health': 236,
#  'change': 308,
#  'piece': 60,
#  'plan': 177,
#  'hope': 163,
#  'cart': 10,
#  'vice': 60,
#  'soccer': 253,
#  'surgery': 63,
#  'multiple': 27,
#  'september': 161,
#  'safety': 235,
#  'cnn': 1010,
#  'rookie': 51,
#  'deadliness': 3,
#  'site': 135,
#  'surface': 45,
#  'miller': 22,
#  'executive': 84,
#  'room': 170,
#  'bakhtiari': 1,
#  'outlook': 10,
#  'rate': 64,
#  'lineman': 16,
#  'tent': 12,
#  'wire': 14,
#  'policy': 183,
#  'anyone': 203,
#  'post': 261,
#  'prevent': 71,
#  'sick': 5,
#  'gipson': 2,
#  'turf': 10,
#  'rutherford': 3,
#  'metlife': 5,
#  'idea': 122,
#  'recovery': 90,
#  'contender': 20,
#  'backup': 11,
#  'care': 162,
#  'discuss': 27,
#  'greenberg': 2,
#  'see': 233,
#  'shanksville': 1,
#  'case': 386,
#  'twitter': 257,
#  'punt': 5,
#  'commitment': 76,
#  'minimum': 11,
#  'longtime': 5,
#  'clarity': 24,
#  'occasion': 75,
#  'playoff': 121,
#  'dissatisfaction': 7,
#  'precision': 14,
#  'maneuvering': 2,
#  'apple': 13,
#  'canniness': 2,
#  'knack': 4,
#  'option': 56,
#  'jordan': 76,
#  'age': 210,
#  'heir': 11,
#  'help': 350,
#  'ben': 37,
#  'wry': 2,
#  'ceo': 63,
#  'veteran': 50,
#  'josh': 34,
#  'bale': 9,
#  'gareth': 2,
#  'gridiron': 3,
#  'davante': 4,
#  'mitchell': 7,
#  'tom': 55,
#  'reception': 27,
#  'tottenham': 24,
#  'tour': 154,
#  'justin': 63,
#  'malnati': 1,
#  'golf': 131,
#  'camp': 76,
#  'tweet': 80,
#  'duo': 52,
#  'rivalry': 26,
#  'pair': 133,
#  'trash': 11,
#  'silverman': 1,
#  'humor': 7,
#  'appreciate': 23,
#  'keith': 9,
#  'joseph': 22,
#  'footballer': 34,
#  'partner': 125,
#  'meanwhile': 88,
#  'sugarcoat': 3,
#  'beach': 43,
#  'footage': 129,
#  'fedex': 6,
#  'presence': 109,
#  'golfer': 64,
#  'training': 202,
#  'trio': 28,
#  'resume': 15,
#  'hear': 27,
#  'peter': 46,
#  'insurance': 22,
#  'spending': 72,
#  'pga': 78,
#  'brendon': 1,
#  'amazing': 12,
#  'brady': 23,
#  'neighborhood': 20,
#  'wait': 86,
#  'become': 139,
#  'smith': 56,
#  'struggle': 42,
#  'countless': 11,
#  'green': 14,
#  'excellent': 6,
#  'aim': 53,
#  'roster': 30,
#  'amongst': 7,
#  'drop': 72,
#  'history': 488,
#  'collection': 25,
#  'environment': 83,
#  'garrett': 7,
#  'podium': 22,
#  'sauce': 7,
#  'fame': 61,
#  'darnold': 1,
#  'slip': 9,
#  'mosley': 2,
#  'tampa': 32,
#  'cornerback': 14,
#  'sword': 11,
#  'gang': 15,
#  'business': 146,
#  'sore': 3,
#  'agency': 277,
#  'gardner': 6,
#  'wilderness': 3,
#  'jigsaw': 4,
#  'position': 354,
#  'kid': 36,
#  'opening': 80,
#  'charity': 65,
#  'theater': 31,
#  'august': 105,
#  'registrar': 1,
#  'sentence': 61,
#  'increase': 110,
#  'delivery': 41,
#  'inquiry': 40,
#  'picket': 2,
#  'decriminalization': 1,
#  'compassion': 17,
#  'racism': 41,
#  'ruling': 52,
#  'decade': 93,
#  'terminate': 9,
#  'prison': 125,
#  'blogger': 48,
#  'director': 233,
#  'outrage': 27,
#  'bpas': 3,
#  'movement': 111,
#  'gestation': 1,
#  'procedure': 29,
#  'proudman': 3,
#  'womb': 1,
#  'poland': 79,
#  'maker': 8,
#  'crime': 110,
#  'protest': 97,
#  'campaigner': 11,
#  'uptake': 2,
#  'access': 169,
#  'conviction': 26,
#  'lawmaker': 24,
#  'legislation': 51,
#  'jennifer': 54,
#  'crisis': 190,
#  'creasy': 1,
#  'stella': 6,
#  'summer': 218,
#  'progress': 134,
#  'decide': 16,
#  'prosecution': 42,
#  'impact': 179,
#  'allow': 19,
#  'cause': 178,
#  'london': 148,
#  'buffer': 5,
#  'threat': 166,
#  'consensus': 17,
#  'limit': 38,
#  'wickham': 1,
#  'encouragement': 7,
#  'ireland': 52,
#  'annabel': 1,
#  'parliament': 160,
#  'example': 155,
#  'issue': 203,
#  'subject': 10,
#  'prevention': 17,
#  'control': 262,
#  'type': 71,
#  'hirsi': 1,
#  'provision': 22,
#  'charlotte': 42,
#  'sowemimo': 1,
#  'argument': 33,
#  'liberalization': 3,
#  'pregnancy': 20,
#  'license': 21,
#  'government': 563,
#  'nadia': 3,
#  'jenny': 5,
#  'letter': 104,
#  'roe': 1,
#  'justice': 150,
#  'barrister': 9,
#  'comfort': 20,
#  'medication': 16,
#  'custody': 71,
#  'person': 317,
#  'fear': 71,
#  'thinking': 36,
#  'actress': 9,
#  'katherine': 6,
#  'landmark': 22,
#  'dean': 10,
#  'abortion': 16,
#  'opposition': 185,
#  'agenda': 23,
#  'offense': 48,
#  'act': 158,
#  'criminalization': 2,
#  'demanding': 3,
#  'voting': 31,
#  'wade': 4,
#  'martínez': 4,
#  'victor': 32,
#  'inter': 45,
#  'jesus': 18,
#  'stake': 33,
#  'wealth': 31,
#  'milan': 59,
#  'perform': 32,
#  'millimeter': 2,
#  'suggestion': 22,
#  'shot': 216,
#  'stefano': 8,
#  'mike': 41,
#  'atmosphere': 5,
#  'kept': 10,
#  'fikayo': 2,
#  'penalty': 124,
#  'manzano': 1,
#  'tie': 41,
#  ...}

# %%
# Total amount of nouns identified in all the articles
len(noun_frequency)
# Out:
# 21676

# %%
word_dict_occ = dict()
for (key, value) in noun_frequency.items():
    if value >= 20:
        word_dict_occ[key] = value
word_dict = word_dict_occ

# %%
# Total amount of nouns in at least 20 articles
len(word_dict)
# Out:
# 2035

# %% [markdown]
# Words that can be found in at least 20 articles

# %%
words = np.array(list(word_dict.keys()))

# %%
words
# Out:
# array(['body', 'brother', 'strike', ..., 'braverman', 'francis',
#        'gerasimov'], dtype='<U16')

# %%
np.save('words.npy', words)

# %% [markdown]
# ### Compute word histogram for articles ###

# %%
zero_histogram = {word: 0 for word in word_dict.keys()}
corpus = dict()

for article_name, article_nouns in articles.items():
    histogram = zero_histogram.copy()
    for word_element in words:
        histogram[word_element] = article_nouns.count(word_element)
    corpus[article_name] = histogram

# %%
with open('corpus.json', 'w', encoding='utf-8') as file:
    json.dump(corpus, file, indent=2)

# %% [markdown]
# ### Process corpus as numpy array ###

# %%
corpus = None

# %%
with open('corpus.json', 'r') as file:
    corpus = json.load(file)

# %%
array_corpus = np.array([[freq for freq in article_nouns.values()] for article_nouns in corpus.values()])

# %%
np.save('corpus.npy', array_corpus)

# %%
with open('artice_names.json', 'w', encoding='utf-8') as f:
    json.dump(list(corpus.keys()), f)
